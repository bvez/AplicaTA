# %% [markdown]
# # Laboratorio 9

# %% [markdown]
# <p>Para este laboratorio, hemos decidido usar un dataset con los tweets que realizaron las personas frente a Apple</p>

# %%
import nltk
import re
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/alulab/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Lectura del archivo de entrada

# %%
import pandas as pd
df = pd.read_csv("Apple-Twitter-Sentiment-DFE.csv", header=0,encoding = 'utf_8')

# %%
df.sample(5)
# Out:
#        _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 3862  623499392    False   finalized                   3    12/11/14 22:10
# 105   623495618    False   finalized                   3    12/11/14 14:28
# 1065  623496584    False   finalized                   3    12/12/14 14:43
# 3012  623498542    False   finalized                   3     12/12/14 2:05
# 650   623496163    False   finalized                   3    12/12/14 13:46
#
#      sentiment  sentiment:confidence                            date  \
# 3862         3                0.7011  Tue Dec 09 21:21:01 +0000 2014
# 105          3                0.6442  Tue Dec 02 03:05:32 +0000 2014
# 1065         3                1.0000  Thu Dec 04 00:38:12 +0000 2014
# 3012         3                1.0000  Mon Dec 08 15:09:59 +0000 2014
# 650          1                1.0000  Wed Dec 03 05:55:28 +0000 2014
#
#                 id            query sentiment_gold  \
# 3862  5.420000e+17  #AAPL OR @Apple            NaN
# 105   5.400000e+17  #AAPL OR @Apple            NaN
# 1065  5.400000e+17  #AAPL OR @Apple            NaN
# 3012  5.420000e+17  #AAPL OR @Apple            NaN
# 650   5.400000e+17  #AAPL OR @Apple            NaN
#
#                                                    text
# 3862  Apple Is Warming Up To Social Media: Apple is ...
# 105   .@Apple rumoured to be launching a 'Mega Tab' ...
# 1065  @Apple iSchool? http://t.co/qpDxDpX3Qj #educat...
# 3012  APPLE - Fibonacci Technicals Levels - Intraday...
# 650   APPLES EARBUDS ARE SO FUCKING WEAK THEY LITERA...

# %% [markdown]
# ## Limpieza de columnas

# %% [markdown]
# Eliminamos las columnas que no aportan informacion en cuanto al sentimiento dentro del texto. Estas columnas son las fechas, identificadores y estados.

# %%
df2 = df.drop(["_unit_id","_unit_state","date","id","query","_last_judgment_at"],axis=1)
df2.sample(5)
# Out:
#       _golden  _trusted_judgments sentiment  sentiment:confidence  \
# 3375    False                   3         3                1.0000
# 1368    False                   3         3                0.6851
# 759     False                   3         3                0.6731
# 537     False                   6         1                0.6772
# 1144    False                   3         3                0.6774
#
#      sentiment_gold                                               text
# 3375            NaN  RT @TeamCavuto: Protesters stage #DieIn protes...
# 1368            NaN  #iPhone6, 6 #Plus trigger spike in #Apple sale...
# 759             NaN  Steve Jobs' Snarky Testimony Takes Center Stag...
# 537             NaN  #Apple Inc. #AAPL News Analysis: Did Apple Inc...
# 1144            NaN  #AAPL:Alabama anti-discrimination bill to be n...

# %% [markdown]
# ## Separacion de datos

# %% [markdown]
# Separamos la columna "sentiment" que es el dato final que queremos lograr. Además dividimos los datos de forma que el 80% de los datos servirá para entrenar y el 20% restante servirá para probar.

# %%
X_all = df2.drop(['sentiment'],axis=1)
y_all = df2['sentiment']
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

num_test = 0
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=num_test)

# %%
import numpy as np
titles =np.array(X_train["text"])
print(X_train["text"])
print(titles[1])
# Out:
# 693     # Dyslexic iPhone 6 Users rejoice! Thanks to @...
# 3378    RT @TeamCavuto: Protesters stage #DieIn protes...
# 1545    RT @OneRepublic: Studio at 45,000 ft.  One out...
# 1400    iOS 8.1 has fucked my battery life on my iPhon...
# 1448           @OneRepublic @Apple 45000 feet keep flying
# 2802    RT @brock_and_r0ll: .@apple fix yourself http:...
# 331               @apple has caused me so much pain today
# 477     RT @JPDesloges: APPLE - Fibonacci Technicals L...
# 801     @jakeflem @Apple Yes It seems to fix it good t...
# 1804    @OneRepublic @Apple aww look tht u have a lot ...
# 2793    @apple's calendar app has judiciously listed v...
# 900     .@Google Trumps @Apple In Streaming Media Sale...
# 3202    @Apple HEY FUCK U MY PHONE SPEAKER NO LONGER W...
# 3672    $AAPL as expected, some users still like small...
# 2236    @Apple my wifi is on &amp; working on everythi...
# 576     Final #AAPL #PutCallRatios for Tuesday, Decemb...
# 632     @dangainor @Apple But then how could they post...
# 1434    RT @OneRepublic: Studio at 45,000 ft.  One out...
# 1462    RT @OneRepublic: Studio at 45,000 ft.  One out...
# 2027    RT @OneRepublic: Studio at 45,000 ft.  One out...
# 3005    Reminiscing on the first low-cost computer whi...
# 3128    RT @AcrossTheBarTV: Our first ever #OnFoodable...
# 1863    @OneRepublic if you'll get it from  @Apple I w...
# 1573             @OneRepublic @Apple THIS IS SO BEAUTIFUL
# 1793    How long is this @apple iOS 8.1.1 update going...
# 2696    'This accessory may not be supported' ok @Appl...
# 3688    .@Apple Store is coming to Brooklyn http://t.c...
# 2903    RT @fakebananas: Thanks @Apple for the preview...
# 1972    On Thursday, December 11th, learn an #HourOfCo...
# 3334    RT @TeamCavuto: Protesters stage #DieIn protes...
#                               ...
# 2981              @apple thank you http://t.co/wmSinAAuQf
# 2535    T-MOBILE/IPHONE CALLING PROBLEM WORK AROUND ht...
# 2409    THE WORLD'S FIRST MURDER VIA FACETIME THANK YO...
# 2747    Here's the @Apple #SmartWatch. I say @HP beats...
# 3290    'Not a book on how @Apple or @Starbucks grow g...
# 3624    RT @JPDesloges: Apple to build major new R&amp...
# 2035    Is Apple Inc. Losing the $5 Billion Ed-Tech Ma...
# 3032    Apple Continues Beefing Up Digital Audio Exper...
# 3065    RT @schreier: It makes you smarter.  Elevate i...
# 1958    The dirty secret in the shadow of Silicon Vall...
# 2840       MY COMPUTER IS NOT TURNING BACK ON HELP @APPLE
# 844                why isn't there a dreidel emoji @apple
# 2101    @apple the fact these itunes updates makes it ...
# 1990    RT @OneRepublic: Studio at 45,000 ft.  One out...
# 2032    @HANNAHRAD Why doesn't @apple give out free ap...
# 2599    @MarkZuckerbergF of @facebook and tim cook of ...
# 2890    @Apple When will you follow through &amp; equi...
# 2649              that was terrifying, suck my ass @apple
# 474     .@apple MacMail on OS X #Yosemite is really gi...
# 564     @caseypieper @TheWeldingRoom @Apple @Monster @...
# 1012    13 Things You Didn't Know Your #iPhone6 Could ...
# 3118    CNBCTV:  Bulls running with #GoPro &amp; #Appl...
# 1543    RT @OneRepublic: Studio at 45,000 ft.  One out...
# 638     #PeterHewer @Apple iPhone 6 claimed to copy a ...
# 595     THE FUTURE OF #APPLE #aapl http://t.co/0MO7dUe...
# 1065    @Apple iSchool? http://t.co/qpDxDpX3Qj #educat...
# 651     Why is Tom automatically capitalized and tommy...
# 3008    @Apple [#Apple] #is developing an #iPhone that...
# 3716    APPLE Intraday Comments - Updated RANGE,. - PR...
# 930     RT @SaifBinS3eed: This new phone sucks I can't...
# Name: text, Length: 3886, dtype: object
# RT @TeamCavuto: Protesters stage #DieIn protests in @Apple store in NYC... Is it me, or is this anger misplaced? RETWEET if you agree.

# %%
import re
text = " ".join(titles) 
titles
# Out:
# array([ "# Dyslexic iPhone 6 Users rejoice! Thanks to @apple and 'voice text' hard to spell words are a thing of the past! http://t.co/wjJfLYZme3",
#        'RT @TeamCavuto: Protesters stage #DieIn protests in @Apple store in NYC... Is it me, or is this anger misplaced? RETWEET if you agree.',
#        'RT @OneRepublic: Studio at 45,000 ft.  One outlet,  4 computers.  @Apple we need the batteries of the future NoW!!!! http://t.co/astp9x6KET',
#        ...,
#        '@Apple [#Apple] #is developing an #iPhone that fires LASER BEAMS to #map surroundings .... (#Monday, 8 #December) http://t.co/D78wUFxrkK',
#        'APPLE Intraday Comments - Updated RANGE,. - PREMIUM USERS  #aapl #Stockaction #trading #Stocks #MKt\r\nhttp://t.co/G0TeDLCB9z',
#        "RT @SaifBinS3eed: This new phone sucks I can't make it stand up or on its side I can't wait for the iPhone 7 @apple fix this you dingles"], dtype=object)

# %% [markdown]
# Eliminación de URLs

# %%
from collections import Counter

for i in range(len(titles)):
    #URLs_dict = Counter( re.findall(r"(https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9]\.[^\s]{2,})",i) )
    #URLs = list(URLs_dict.keys())
    titles[i] = re.sub(r"(https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9]\.[^\s]{2,})","", titles[i])
titles
# Out:
# array([ "# Dyslexic iPhone 6 Users rejoice! Thanks to @apple and 'voice text' hard to spell words are a thing of the past! ",
#        'RT @TeamCavuto: Protesters stage #DieIn protests in @Apple store in NYC... Is it me, or is this anger misplaced? RETWEET if you agree.',
#        'RT @OneRepublic: Studio at 45,000 ft.  One outlet,  4 computers.  @Apple we need the batteries of the future NoW!!!! ',
#        ...,
#        '@Apple [#Apple] #is developing an #iPhone that fires LASER BEAMS to #map surroundings .... (#Monday, 8 #December) ',
#        'APPLE Intraday Comments - Updated RANGE,. - PREMIUM USERS  #aapl #Stockaction #trading #Stocks #MKt\r\n',
#        "RT @SaifBinS3eed: This new phone sucks I can't make it stand up or on its side I can't wait for the iPhone 7 @apple fix this you dingles"], dtype=object)

# %% [markdown]
# Se obtienen todas las siglas presentes en los textos, ya sean un conjunto de 2 o más letras mayúsculas o separadas
# por punto.

# %%
from collections import Counter
my_dict = Counter( re.findall(r"[A-Z][A-Z]+",text) )
siglas = list(my_dict.keys())
my_dict2 = Counter(re.findall(r"([A-Z]\.([A-Z]\.)+)",text))
siglas2 = list(my_dict2.keys())

sig =[]
for i in siglas2:
    sig.append(i[0])
siglas = sig + siglas
siglas
# Out:
# ['L.A.',
#  'U.S.',
#  'D.C.',
#  'LYZ',
#  'RT',
#  'NYC',
#  'RETWEET',
#  'KET',
#  'OS',
#  'GF',
#  'JPD',
#  'APPLE',
#  'LAST',
#  'AAPL',
#  'XO',
#  'DW',
#  'AILF',
#  'HEY',
#  'FUCK',
#  'MY',
#  'PHONE',
#  'SPEAKER',
#  'NO',
#  'LONGER',
#  'WORKS',
#  'JUST',
#  'QD',
#  'TWO',
#  'DAYS',
#  'GET',
#  'IT',
#  'TOGETHER',
#  'NASDAQ',
#  'TWTR',
#  'FB',
#  'SFLY',
#  'YH',
#  'TV',
#  'MFK',
#  'WN',
#  'THIS',
#  'IS',
#  'SO',
#  'BEAUTIFUL',
#  'OU',
#  'WAGN',
#  'SDN',
#  'WORLD',
#  'CP',
#  'PC',
#  'GU',
#  'DFH',
#  'CNBC',
#  'CL',
#  'XF',
#  'ZN',
#  'JN',
#  'BY',
#  'YWXB',
#  'USPTO',
#  'BLOCK',
#  'TRADE',
#  'HELD',
#  'CLOSE',
#  'TO',
#  'CHEEK',
#  'AND',
#  'GAVE',
#  'ME',
#  'SHOCK',
#  'OHHSHIT',
#  'HELP',
#  'LT',
#  'WTOW',
#  'TG',
#  'JWZ',
#  'TAT',
#  'AM',
#  'LB',
#  'QS',
#  'SC',
#  'VJ',
#  'CU',
#  'GI',
#  'ZX',
#  'JC',
#  'NC',
#  'SY',
#  'UBS',
#  'RANGE',
#  'PREMIUM',
#  'USERS',
#  'MK',
#  'DLCB',
#  'ATT',
#  'US',
#  'II',
#  'BDSM',
#  'BWC',
#  'NH',
#  'TH',
#  'EUR',
#  'CEO',
#  'FQQ',
#  'TWD',
#  'SSNLF',
#  'BL',
#  'GV',
#  'WX',
#  'TE',
#  'YU',
#  'GD',
#  'MB',
#  'JU',
#  'WWDC',
#  'QY',
#  'NEW',
#  'YORK',
#  'WP',
#  'FN',
#  'HTC',
#  'AIDS',
#  'IEL',
#  'NRIK',
#  'NT',
#  'IP',
#  'XY',
#  'IBDB',
#  'IBD',
#  'HU',
#  'GW',
#  'VUHNX',
#  'CVHG',
#  'GT',
#  'KW',
#  'FL',
#  'AR',
#  'TIME',
#  'IO',
#  'MQ',
#  'ARI',
#  'ID',
#  'FIOS',
#  'STB',
#  'DUC',
#  'GLW',
#  'FQ',
#  'LR',
#  'JP',
#  'RA',
#  'JI',
#  'LC',
#  'QMOK',
#  'PO',
#  'FE',
#  'PS',
#  'WMT',
#  'BQ',
#  'JG',
#  'BO',
#  'AGAIN',
#  'PL',
#  'OSX',
#  'ULM',
#  'GLQ',
#  'KIM',
#  'SN',
#  'TD',
#  'WA',
#  'OWS',
#  'ACA',
#  'ZD',
#  'IE',
#  'ZH',
#  'AF',
#  'JK',
#  'GLUU',
#  'KUY',
#  'UT',
#  'SS',
#  'DX',
#  'PZ',
#  'ZO',
#  'RG',
#  'CS',
#  'UNLV',
#  'OYDO',
#  'XH',
#  'OV',
#  'ZK',
#  'AS',
#  'RCP',
#  'CRI',
#  'KT',
#  'CW',
#  'DG',
#  'AN',
#  'IGN',
#  'OAV',
#  'CQY',
#  'IZN',
#  'SD',
#  'DUNS',
#  'PGC',
#  'SLA',
#  'SELL',
#  'OR',
#  'HOLD',
#  'BEA',
#  'FA',
#  'FRUSTRATING',
#  'KUK',
#  'VT',
#  'YF',
#  'FAQ',
#  'UK',
#  'RK',
#  'OL',
#  'KDLEFLM',
#  'LNKD',
#  'GOOGL',
#  'TSLA',
#  'FRN',
#  'MM',
#  'NYD',
#  'BCO',
#  'HB',
#  'JT',
#  'RNR',
#  'YOUR',
#  'SHIT',
#  'LL',
#  'GUY',
#  'SAMSUNG',
#  'GALAXY',
#  'LEH',
#  'DDKX',
#  'JB',
#  'PKX',
#  'ASMSG',
#  'BR',
#  'REPORT',
#  'AI',
#  'PM',
#  'AYM',
#  'WHAT',
#  'THE',
#  'HELL',
#  'LIMF',
#  'MX',
#  'VPN',
#  'FFS',
#  'NSA',
#  'XC',
#  'RWTT',
#  'HYS',
#  'BX',
#  'UBR',
#  'KKAU',
#  'OSIY',
#  'SJ',
#  'UI',
#  'BOOLVP',
#  'CQI',
#  'WMX',
#  'OQ',
#  'YMZ',
#  'WNC',
#  'AMCT',
#  'JZ',
#  'DXV',
#  'IH',
#  'HM',
#  'RN',
#  'BREAKING',
#  'MUSIC',
#  'KF',
#  'UL',
#  'XXK',
#  'TI',
#  'DRM',
#  'WHY',
#  'CAN',
#  'DATE',
#  'CLONE',
#  'ST',
#  'FREE',
#  'TK',
#  'VS',
#  'RO',
#  'WK',
#  'AMZN',
#  'BABA',
#  'ALL',
#  'IM',
#  'SOOOOO',
#  'SLEEP',
#  'FIX',
#  'OK',
#  'XE',
#  'EW',
#  'AVGO',
#  'JD',
#  'KG',
#  'GYL',
#  'GMONEY',
#  'SU',
#  'KP',
#  'PICK',
#  'UP',
#  'SLACK',
#  'YOU',
#  'BOYS',
#  'GBAS',
#  'QNM',
#  'RS',
#  'RJ',
#  'LO',
#  'AD',
#  'CALLER',
#  'BLOCKED',
#  'CFD',
#  'YVX',
#  'PUD',
#  'CX',
#  'LUV',
#  'GS',
#  'MT',
#  'XFT',
#  'HATE',
#  'MUCH',
#  'RUIN',
#  'LIFE',
#  'RE',
#  'NOT',
#  'EVEN',
#  'REAL',
#  'FUCKING',
#  'COMPANY',
#  'SUPPOSED',
#  'DO',
#  'GL',
#  'MFN',
#  'MAL',
#  'OW',
#  'ZYW',
#  'KQ',
#  'RKEV',
#  'BP',
#  'CNBCTV',
#  'KTB',
#  'SMFH',
#  'MAIL',
#  'SEARCH',
#  'FOR',
#  'FILE',
#  'FINDER',
#  'XMFV',
#  'EX',
#  'KM',
#  'MV',
#  'CAME',
#  'WITH',
#  'PURCHASE',
#  'OF',
#  'FINAL',
#  'CUT',
#  'PRO',
#  'OO',
#  'GVA',
#  'WIN',
#  'DIGITAL',
#  'MAKEOVER',
#  'GIVEAWAY',
#  'GC',
#  'IPAD',
#  'MACBOOK',
#  'MORE',
#  'SI',
#  'PIN',
#  'BK',
#  'ORJS',
#  'SMD',
#  'IDE',
#  'EQU',
#  'NI',
#  'QFRD',
#  'TZ',
#  'AO',
#  'CJ',
#  'AV',
#  'CAZ',
#  'USELESS',
#  'KQH',
#  'PB',
#  'JH',
#  'BMS',
#  'BMO',
#  'DV',
#  'EP',
#  'CM',
#  'BS',
#  'GE',
#  'BYJ',
#  'ZR',
#  'QU',
#  'OYLI',
#  'KILLING',
#  'GP',
#  'FZR',
#  'NFC',
#  'DOES',
#  'HBS',
#  'OVERTAKE',
#  'HOSTW',
#  'CNET',
#  'SV',
#  'VJREH',
#  'AL',
#  'ZA',
#  'ASAP',
#  'BE',
#  'YG',
#  'DP',
#  'LSZ',
#  'IG',
#  'COMPUTING',
#  'COMMUNICATION',
#  'ROM',
#  'PT',
#  'LNH',
#  'FTD',
#  'WM',
#  'WR',
#  'EZ',
#  'WZ',
#  'SX',
#  'UCK',
#  'YZ',
#  'MA',
#  'RVI',
#  'TF',
#  'YHIS',
#  'OHONE',
#  'OMG',
#  'EMBARRASSED',
#  'TAUS',
#  'AP',
#  'JMH',
#  'JMP',
#  'XW',
#  'IU',
#  'BBRY',
#  'QCR',
#  'MC',
#  'KMREV',
#  'NTLS',
#  'TMUS',
#  'EV',
#  'NV',
#  'VUMG',
#  'HP',
#  'RV',
#  'GSBX',
#  'OFXT',
#  'CHAYILT',
#  'QRVLW',
#  'MS',
#  'LU',
#  'QP',
#  'KMNHC',
#  'TP',
#  'HATW',
#  'RED',
#  'OB',
#  'VI',
#  'QN',
#  'OP',
#  'DIY',
#  'PGO',
#  'AIRMILES',
#  'BTC',
#  'OWV',
#  'DF',
#  'DCA',
#  'EPOO',
#  'WSV',
#  'LS',
#  'QF',
#  'MOBILE',
#  'CELLULAR',
#  'TM',
#  'UBT',
#  'NZ',
#  'ZU',
#  'IX',
#  'VU',
#  'BXTB',
#  'KXY',
#  'FR',
#  'LTF',
#  'UOI',
#  'NY',
#  'DOW',
#  'DEAR',
#  'WORSE',
#  'SERVICE',
#  'EVER',
#  'JHP',
#  'ZV',
#  'HS',
#  'DT',
#  'JYZOGI',
#  'QO',
#  'HO',
#  'WTF',
#  'ILUUN',
#  'UY',
#  'EPS',
#  'CBU',
#  'EHZS',
#  'YYCOY',
#  'AH',
#  'BI',
#  'OMT',
#  'THINK',
#  'NF',
#  'REM',
#  'NYT',
#  'IKM',
#  'BEST',
#  'ZERO',
#  'NPTO',
#  'WO',
#  'ON',
#  'YO',
#  'AINT',
#  'KI',
#  'OVER',
#  'OML',
#  'BABYYYSS',
#  'VAE',
#  'IN',
#  'FACE',
#  'RGTB',
#  'IPHONE',
#  'LTE',
#  'CALL',
#  'WORK',
#  'AROUND',
#  'AW',
#  'FZCW',
#  'KBM',
#  'RHHE',
#  'NW',
#  'LOL',
#  'SIRI',
#  'NOTHING',
#  'OOL',
#  'ER',
#  'JTPO',
#  'MWUB',
#  'DL',
#  'ANF',
#  'TJX',
#  'TGT',
#  'LYV',
#  'SNE',
#  'GBP',
#  'VO',
#  'XNKM',
#  'RVF',
#  'SFZF',
#  'QNYAM',
#  'IC',
#  'PKK',
#  'LSP',
#  'PE',
#  'POLICE',
#  'GOVT',
#  'UN',
#  'DUT',
#  'XQDU',
#  'VR',
#  'WUJ',
#  'WQ',
#  'SFBJN',
#  'SFBJE',
#  'RD',
#  'ZES',
#  'YC',
#  'DK',
#  'KEB',
#  'SHOQS',
#  'UPDATE',
#  'FOLLOW',
#  'PLS',
#  'SIM',
#  'MH',
#  'FXEUX',
#  'ND',
#  'LVROPD',
#  'KNHGE',
#  'WES',
#  'KK',
#  'QQ',
#  'HAVE',
#  'BEEN',
#  'THROUGH',
#  'ABOUT',
#  'CHARGERS',
#  'XP',
#  'UQ',
#  'SATA',
#  'DEAD',
#  'EY',
#  'JJ',
#  'AODR',
#  'HN',
#  'ED',
#  'CJB',
#  'HH',
#  'FC',
#  'EM',
#  'OKI',
#  'IKEA',
#  'IDSA',
#  'VX',
#  'HI',
#  'AX',
#  'DTJ',
#  'OPERATION',
#  'PAPERCLIP',
#  'ACTUAL',
#  'EE',
#  'GHN',
#  'JW',
#  'TLP',
#  'MRY',
#  'WVD',
#  'YN',
#  'LKK',
#  'MD',
#  'EB',
#  'PEN',
#  'AJIR',
#  'YES',
#  'LOVE',
#  'WHEN',
#  'NONE',
#  'STUFF',
#  'THANK',
#  'MF',
#  'EOF',
#  'LGBT',
#  'DNYI',
#  'VZ',
#  'HD',
#  'CH',
#  'EK',
#  'ES',
#  'TC',
#  'QE',
#  'LCA',
#  'XK',
#  'HRH',
#  'EQ',
#  'KR',
#  'TRES',
#  'SUCK',
#  'SDGLN',
#  'VY',
#  'FBI',
#  'BTJ',
#  'UW',
#  'NM',
#  'FJEXI',
#  'TMA',
#  'ATTC',
#  'XIW',
#  'BGP',
#  'BW',
#  'OE',
#  'OI',
#  'GXP',
#  'MBP',
#  'BHP',
#  'AA',
#  'QFC',
#  'QSDV',
#  'EQYG',
#  'CJDMB',
#  'GO',
#  'VSU',
#  'BPCT',
#  'UX',
#  'ZY',
#  'GX',
#  'LG',
#  'VB',
#  'LA',
#  'DRZ',
#  'JV',
#  'YKVL',
#  'AFP',
#  'RZQ',
#  'DN',
#  'DM',
#  'MI',
#  'LIVE',
#  'RR',
#  'POH',
#  'LE',
#  'VIRUS',
#  'TGIBDD',
#  'POS',
#  'EO',
#  'YEA',
#  'EF',
#  'OG',
#  'HE',
#  'GN',
#  'XU',
#  'VWY',
#  'FT',
#  'PUSH',
#  'JDQ',
#  'APP',
#  'STORE',
#  'IPA',
#  'CN',
#  'NNF',
#  'ITS',
#  'TRIPPING',
#  'TIRED',
#  'BULLSHIT',
#  'HOLDING',
#  'RESPONSIBLE',
#  'MBHI',
#  'TFQVO',
#  'MW',
#  'CG',
#  'CC',
#  'GPRO',
#  'EGA',
#  'NORMAL',
#  'ABUSE',
#  'AB',
#  'HA',
#  'IOS',
#  'STILL',
#  'ORDA',
#  'PMO',
#  'MMA',
#  'AMAN',
#  'AIMAI',
#  'ZJ',
#  'MN',
#  'DU',
#  'HR',
#  'FKW',
#  'PR',
#  'SG',
#  'DOIS',
#  'BDZE',
#  'LF',
#  'PSTALUKE',
#  'AMN',
#  'DAMM',
#  'DAMN',
#  'SBD',
#  'LI',
#  'BGR',
#  'VYI',
#  'DD',
#  'IRL',
#  'EKIE',
#  'UTC',
#  'TBJA',
#  'NS',
#  'CI',
#  'VK',
#  'DZ',
#  'REU',
#  'DUI',
#  'VC',
#  'KJ',
#  'WORST',
#  'DAY',
#  'PU',
#  'ZF',
#  'YLL',
#  'SKV',
#  'LN',
#  'RKS',
#  'LX',
#  'PKV',
#  'BV',
#  'OH',
#  'GOD',
#  'DONT',
#  'PLAY',
#  'FORREAL',
#  'IMHO',
#  'BTW',
#  'GB',
#  'UBLAZ',
#  'YX',
#  'ESPN',
#  'RONG',
#  'MP',
#  'QXD',
#  'HAPPENED',
#  'OMD',
#  'BU',
#  'ZOLP',
#  'SA',
#  'SW',
#  'SL',
#  'HOW',
#  'PN',
#  'WOW',
#  'CB',
#  'SPUTNIK',
#  'INSAT',
#  'WANT',
#  'STAY',
#  'NOW',
#  'RW',
#  'PX',
#  'CV',
#  'YS',
#  'LBVYE',
#  'HZ',
#  'MHYX',
#  'QFN',
#  'APPL',
#  'HX',
#  'YV',
#  'MZP',
#  'NBCN',
#  'NYPDC',
#  'ISIS',
#  'OAYTLQ',
#  'QH',
#  'QW',
#  'UUQB',
#  'OAK',
#  'ZE',
#  'CJO',
#  'FQR',
#  'BZ',
#  'SZ',
#  'YW',
#  'QJKK',
#  'DID',
#  'IPOD',
#  'CHANGE',
#  'ORDER',
#  'SONGS',
#  'PLAYLIST',
#  'ALWAYS',
#  'LISTEN',
#  'FLYING',
#  'ISNT',
#  'OKAY',
#  'AFC',
#  'WANNA',
#  'HUG',
#  'THEM',
#  'EWV',
#  'DOB',
#  'PRK',
#  'YJVG',
#  'KL',
#  'BB',
#  'FUI',
#  'RZOX',
#  'WG',
#  'JSDFL',
#  'CALLING',
#  'PROBLEM',
#  'EGYFOH',
#  'VZJ',
#  'TDR',
#  'WVJ',
#  'LH',
#  'IF',
#  'QIW',
#  'SP',
#  'EPG',
#  'ZDV',
#  'LV',
#  'LY',
#  'AT',
#  'GK',
#  'PI',
#  'JY',
#  'KPX',
#  'TJL',
#  'TS',
#  'EJ',
#  'LASER',
#  'BEAMS',
#  'PD',
#  'AY',
#  'ZKNK',
#  'USZ',
#  'UGTZ',
#  'NFLX',
#  'PCLN',
#  'SMH',
#  'JX',
#  'UPS',
#  'EL',
#  'YAQ',
#  'BT',
#  'WJ',
#  'FK',
#  'TL',
#  'LK',
#  'CA',
#  'SJS',
#  'ZI',
#  'BBC',
#  'DXPPUWJ',
#  'YEAH',
#  'UR',
#  'SLACKIN',
#  'FSH',
#  'RX',
#  'KDAJ',
#  'DAWASHINGTON',
#  'TLZQ',
#  'LQBT',
#  'YZAOJ',
#  'TY',
#  'BC',
#  'NVRAM',
#  'IA',
#  'ISN',
#  'QGQ',
#  'WXZ',
#  'GR',
#  'KXA',
#  'CDO',
#  'WIY',
#  'MZB',
#  'WWA',
#  'BHA',
#  'OSQ',
#  'GUC',
#  'FZ',
#  'ZDX',
#  'UWW',
#  'ZC',
#  'XBMC',
#  'SPORTS',
#  'ADULTS',
#  'CHANNELS',
#  'NQ',
#  'DIDNT',
#  'DESERVE',
#  'IR',
#  'JKI',
#  'MHI',
#  'XJ',
#  'GH',
#  'SR',
#  'YCE',
#  'LAPTOP',
#  'WONT',
#  'FUCJING',
#  'TURN',
#  'CHARGE',
#  'DIDNG',
#  'PAY',
#  'XX',
#  'PJHE',
#  'PA',
#  'IBM',
#  'SNRTG',
#  'BMRTG',
#  'BTRTG',
#  'TKUBCI',
#  'JR',
#  'WSJ',
#  'BZGC',
#  'HEA',
#  'RAM',
#  'AHT',
#  'FXAZ',
#  'PBE',
#  'BPRQ',
#  'MAKE',
#  'SUCH',
#  'GOOD',
#  'PRODUCTS',
#  'WOULD',
#  'BOYCOTT',
#  ...]

# %% [markdown]
# Como todos los tweets son de idioma inglés se puede quitar las palabras que no aportan (stopwords) y se puede aplicar lemmatization y stem, se intentan conservar las mayúsculas, pues, en un tweet, se usan las mayúsculas para remarcar una idea, normalmente expresa incomodidad u odio.

# %%
import nltk
nltk.download('stopwords')
stopwords_eng = nltk.corpus.stopwords.words('english')
print(stopwords_eng)
stopwords_MAY_eng = list((" ".join([token.upper() for token in stopwords_eng])).split())
stopwords_MAY_eng
# Out:
# [nltk_data] Downloading package stopwords to /home/alulab/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# ['I',
#  'ME',
#  'MY',
#  'MYSELF',
#  'WE',
#  'OUR',
#  'OURS',
#  'OURSELVES',
#  'YOU',
#  "YOU'RE",
#  "YOU'VE",
#  "YOU'LL",
#  "YOU'D",
#  'YOUR',
#  'YOURS',
#  'YOURSELF',
#  'YOURSELVES',
#  'HE',
#  'HIM',
#  'HIS',
#  'HIMSELF',
#  'SHE',
#  "SHE'S",
#  'HER',
#  'HERS',
#  'HERSELF',
#  'IT',
#  "IT'S",
#  'ITS',
#  'ITSELF',
#  'THEY',
#  'THEM',
#  'THEIR',
#  'THEIRS',
#  'THEMSELVES',
#  'WHAT',
#  'WHICH',
#  'WHO',
#  'WHOM',
#  'THIS',
#  'THAT',
#  "THAT'LL",
#  'THESE',
#  'THOSE',
#  'AM',
#  'IS',
#  'ARE',
#  'WAS',
#  'WERE',
#  'BE',
#  'BEEN',
#  'BEING',
#  'HAVE',
#  'HAS',
#  'HAD',
#  'HAVING',
#  'DO',
#  'DOES',
#  'DID',
#  'DOING',
#  'A',
#  'AN',
#  'THE',
#  'AND',
#  'BUT',
#  'IF',
#  'OR',
#  'BECAUSE',
#  'AS',
#  'UNTIL',
#  'WHILE',
#  'OF',
#  'AT',
#  'BY',
#  'FOR',
#  'WITH',
#  'ABOUT',
#  'AGAINST',
#  'BETWEEN',
#  'INTO',
#  'THROUGH',
#  'DURING',
#  'BEFORE',
#  'AFTER',
#  'ABOVE',
#  'BELOW',
#  'TO',
#  'FROM',
#  'UP',
#  'DOWN',
#  'IN',
#  'OUT',
#  'ON',
#  'OFF',
#  'OVER',
#  'UNDER',
#  'AGAIN',
#  'FURTHER',
#  'THEN',
#  'ONCE',
#  'HERE',
#  'THERE',
#  'WHEN',
#  'WHERE',
#  'WHY',
#  'HOW',
#  'ALL',
#  'ANY',
#  'BOTH',
#  'EACH',
#  'FEW',
#  'MORE',
#  'MOST',
#  'OTHER',
#  'SOME',
#  'SUCH',
#  'NO',
#  'NOR',
#  'NOT',
#  'ONLY',
#  'OWN',
#  'SAME',
#  'SO',
#  'THAN',
#  'TOO',
#  'VERY',
#  'S',
#  'T',
#  'CAN',
#  'WILL',
#  'JUST',
#  'DON',
#  "DON'T",
#  'SHOULD',
#  "SHOULD'VE",
#  'NOW',
#  'D',
#  'LL',
#  'M',
#  'O',
#  'RE',
#  'VE',
#  'Y',
#  'AIN',
#  'AREN',
#  "AREN'T",
#  'COULDN',
#  "COULDN'T",
#  'DIDN',
#  "DIDN'T",
#  'DOESN',
#  "DOESN'T",
#  'HADN',
#  "HADN'T",
#  'HASN',
#  "HASN'T",
#  'HAVEN',
#  "HAVEN'T",
#  'ISN',
#  "ISN'T",
#  'MA',
#  'MIGHTN',
#  "MIGHTN'T",
#  'MUSTN',
#  "MUSTN'T",
#  'NEEDN',
#  "NEEDN'T",
#  'SHAN',
#  "SHAN'T",
#  'SHOULDN',
#  "SHOULDN'T",
#  'WASN',
#  "WASN'T",
#  'WEREN',
#  "WEREN'T",
#  'WON',
#  "WON'T",
#  'WOULDN',
#  "WOULDN'T"]

# %%
for i in range(len(titles)):
    titles[i] = " ".join([token for token in titles[i].split() if (token not in stopwords_eng and token not in stopwords_MAY_eng )])
    #len(text.split()) - len(text2.split())

text2 = " ".join([token for token in text.split() if (token not in stopwords_eng and token not in stopwords_MAY_eng )])
titles
# Out:
# array([ "# Dyslexic iPhone 6 Users rejoice! Thanks @apple 'voice text' hard spell words thing past!",
#        'RT @TeamCavuto: Protesters stage #DieIn protests @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#        'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need batteries future NoW!!!!',
#        ...,
#        '@Apple [#Apple] #is developing #iPhone fires LASER BEAMS #map surroundings .... (#Monday, 8 #December)',
#        'APPLE Intraday Comments - Updated RANGE,. - PREMIUM USERS #aapl #Stockaction #trading #Stocks #MKt',
#        "RT @SaifBinS3eed: This new phone sucks can't make stand side can't wait iPhone 7 @apple fix dingles"], dtype=object)

# %%
print("Sin stop words: ")
my_dicc_No_StopWords = Counter(text2.split())

print("cant tokens: ",len(text2.split()))
print("tamanho vocabulario: ",len(my_dicc_No_StopWords))

my_dicc_No_StopWords.most_common(10)
# Out:
# Sin stop words:
# cant tokens:  44591
# tamanho vocabulario:  12724
# [('@Apple', 1621),
#  ('@apple', 982),
#  ('RT', 847),
#  ('Apple', 495),
#  ('#aapl', 462),
#  ('#AAPL', 408),
#  ('need', 391),
#  ('-', 373),
#  ('4', 344),
#  ('One', 322)]

# %%
porter = nltk.PorterStemmer()
import copy

tweets_st =[]
for i in range(len(titles)):
    copia1 = copy.deepcopy(titles[i])

    spliteado = copia1.split()
    tweets_stem_split = []
    for i in spliteado:
        if(i not in siglas):
            tweets_stem_split.append(porter.stem(i))
        else:
            tweets_stem_split.append(i)
    tweets_stem = " ".join([token for token in tweets_stem_split])
    tweets_st.append(tweets_stem)
tweets_st
# Out:
# ["# dyslex iphon 6 user rejoice! thank @appl 'voic text' hard spell word thing past!",
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'io 8.1 fuck batteri life iphon 6. realli start wonder @appl qualiti control anymore. wish 8.01',
#  '@onerepubl @appl 45000 feet keep fli',
#  'RT @brock_and_r0ll: .@appl fix',
#  '@appl caus much pain today',
#  'RT @jpdesloges: APPLE - fibonacci technic level - LAST intraday updat - $aapl #aapl',
#  '@jakeflem @appl ye It seem fix good first time time pass deterio chang logic board',
#  '@onerepubl @appl aww look tht u lot work guy good luck!',
#  "@apple' calendar app judici list virtual everi holiday imagin - yet neglect birthday.",
#  '.@googl trump @appl In stream media sale',
#  '@appl HEY FUCK U PHONE SPEAKER LONGER WORKS b/c',
#  '$aapl expected, user still like small screens, iphon 6 mini reportedli way #aapl',
#  "@appl wifi &amp; work everyth els ipad. i'm pissed. TWO DAYS like this! GET TOGETHER #appl",
#  'final #aapl #putcallratio tuesday, decemb 2, 2014',
#  '@dangainor @appl but could post twitter (nasdaq: twtr), instagram (nasdaq: fb) shutterfli (nasdaq: sfly)? #shutitdown',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'reminisc first low-cost comput which, box, geek use. @appl',
#  'RT @acrossthebartv: our first ever #onfoodableweekly! much discuss episode! @appl pay, @habitburg',
#  '@onerepubl get @appl want one too!',
#  '@onerepubl @appl BEAUTIFUL',
#  'how long @appl io 8.1.1 updat go take?!',
#  "'thi accessori may supported' ok @appl tell charger came phone work???",
#  '.@appl store come brooklyn',
#  'RT @fakebananas: thank @appl preview smartwatch. #fitnesstrack #quantifiedself #iot',
#  'On thursday, decemb 11th, learn #hourofcod @appl store world! reserv spot today! @codeorg',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  "i'm learn appl store @influenster! @appl",
#  'RT @jpdesloges: whi AAPL stock had mini-flash crash today $aapl #aapl',
#  '@appl patent #iphon drop protect mechanism. Is end #crackedscreens?',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'new 4-inch iphon 6 reported. 5 reason appl must make It $aapl #aapl',
#  '@onerepubl @appl bet get radioshack lol',
#  '@w__w @appl @android @minuum custom equal important, treat way. both key, focus one market.',
#  '@onerepubl @appl 45,000 feet keeeppppp flyinggggg',
#  '@fcbliam @appl fix',
#  '#appl question whether ipod class action suit proceed case may lack genuin ... - #aapl #eddycu',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "cheeki @apple... veri cheeky.... No dice though... you can't 'app store' descript product -",
#  '#cnbc make poor #cl got slam like #aapl yesterday.yesterday. pisini pleas put clown shoe report',
#  'Is #appl the most import stock On earth? - appl inc. #aapl | seek alpha',
#  "thi one chart explain @tim_cook' affect @apple. paint interest story. what think?",
#  "@appl grant patent tech shift iphone' center-mass fall prevent damag screen #uspto",
#  "wouldn't bad idea bring back tap tweet function guy @appl @twitter",
#  'BLOCK TRADE detect #aapl',
#  '#appl - #samsung back court @appl @samsungmobil',
#  "@facebook founder attack @appl boss 'ridiculous' comment",
#  'HELD PHONE CLOSE CHEEK GAVE SHOCK OHHSHIT @appl HELP',
#  'RT @jpdesloges: APPLE - fibonacci technic level - intraday updat - $aapl #aapl',
#  'appl Is warm Up To social media: appl hire social media guru L.A. will @appl final tweet?her...',
#  'footag apple-1 comput running. #computerhistori @appl @christiesinc',
#  'comput sux @appl fix',
#  'the @appl iwatch: chang face watch #applenew #iwatch #gadget',
#  'appl inc. To open 500 store In india #aapl',
#  'good huge RT @thehil justic depart cite 18th centuri feder law get @appl unlock iphones:',
#  '3 simpl thing #investor ought know befor buy #stock (#aapl)',
#  'steve job predict futur Of e-commerc back In 1996 &amp; got It exactli right! via @sai #ecommerc #aapl',
#  'appl enter era secur fear-mongering... secur vendor $aapl #aapl',
#  '#onthisdayindigit @appl sign deal china today 2013 final sell #iphon countri',
#  "@mrbeagleman @kronyk @appl that coffee' even fair trade!",
#  '@appl go fix map app. the navig sucks!!! face switch googl maps.',
#  '@cleosbaby64 @appl @stackizshort thank you good coverag W/ nofear',
#  'RT @optionsfeed: final #aapl #putcallratio monday, decemb 8, 2014 via hamzei $$',
#  "@appl @stevejob @itunesmus yooo fam 48 hour where' email back need @jcolenc album drop",
#  'appl get price target boost back strong iphon demand $aapl #aapl',
#  "thank @appl 'do disturb' featur",
#  'UBS say consensu decemb quarter appl iphon unit could 10% low $aapl #aapl',
#  'APPLE intraday comment - updat range,,, - PREMIUM USERS #aapl #stockact #trade #stock #mkt',
#  'pleas make gold macbook @appl',
#  'not sure wors @att @appl vacat @sovereignbanku',
#  '@window funni need old @appl @mac promot new @lenovo #applesetsthetrend',
#  "apple' best itun store 2014: 'elevate' 'pixelmator' win top app honor #aapl",
#  "fail poli sci fuck laptop i'm su @appl",
#  '#music alway part life, everyday @appl also import music',
#  'appl ! @appl',
#  'veri displeas lack #bdsm theme #emojis. @appl @android',
#  'what everi young #design should know, from legendari @appl design susan kare',
#  'spent 6000 EUR apple. iphon 6 camera longer works.told got water it,i not. unaccept custom servic @appl',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '@appl you know iphon fuck letter screen goe back-to-front..',
#  'fuck messag sent email phone number @appl',
#  'appl CEO tim cook come gay @appl via @posh360_net',
#  'twdancecent #urbannutcrack @appl store boylston st. @ 6.30pm. enjoy #krump . meet director &amp; @russellferg',
#  '#samsung: how will the #galaxi #note5 improv On it predecessor? #ssnlf #aapl',
#  "could realli kick @appl 's ass. thi iphon 6 batteri suck moldi dick tuesday night ! worst shit ever. onli last 4 fuck hours.",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'sinc @appl stop replac iphon unit due defect? just scratch phone mean drop it.',
#  'phone drop happened?? @appl wanna help',
#  '#appl just patent An idea that #stevejob would have hate #aapl',
#  '#iphone6, 6 #plu trigger spike #appl sale worldwid - via #aapl',
#  "@gr8american23 i'v made clear support rand paul 2016 cases. everyon pigeonhol red blue? also u like @apple?",
#  'APPLE intraday comment - updat RANGE - PREMIUM USERS #aapl #stockact #trade #stock #mkt',
#  '#appl campu 2 decemb 2014 updat + drone flyover video - #aapl #companytag',
#  '#appl plan spend $161 million auditorium ... - #aapl #wwdc',
#  '@appl YH new appl tumbl much 6 percent unusu trading: By chuck mikolajczak NEW YORK (reuters) ...',
#  'RT @cruci0btch: harri potter emoji pleas work @appl',
#  '@lydiaslyf @bionicbombshel @appl appl better get work',
#  'RT @shannonmmiller: love @appl support #hourofcod workshops! :)',
#  'iphone6 plu imposs hold without cover slide hand #appl #iphon @appl',
#  '#iscuba 360 degre camera rig cloud mobil game surfac #imask @googl @padi @appl @samsung @htc #underwaterwear #cardboard #pivot',
#  '#aapl launch red #appl logo world AIDS day: dec. 1 world AIDS day red appl logo abl...',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  '@appl @tim_cook 28 mb ! whi need wifi instal it????',
#  "In trickl inform @appl releas healthkit @vincekura note 'go braid' strategi #hcub2014",
#  'appl question plaintiff ipod purchas date ongo class-act lawsuit [io blog] #aapl',
#  '@tim_cook not happi @appl @appstor backward compat given. It app aperture?? money grab?',
#  'RT @mrushh: hey @appl phone die charger ur stuff suck',
#  'first 2600 digit languag IP NEW leader internet. term base performance! .@appl .@samsung',
#  'hey @appl catch fuck maverick wave iphone? think so. #surfsupsamsung',
#  "RT @hsmoghul: My @appl autocorrect chang muslim awesom i'm okay",
#  "#appl 'hoarding' #iphone6 suppli store #ibdblog via @ibdinvestor #aapl",
#  'anyon know fix this? #xcode @appl simulators... tri complet reinstal #io',
#  'whi #yosemit constantli restart due error left night? #onlym @appl',
#  '@appl [#apple] #patent An #iphon drop protect mechan that chang devic .... (#tuesday, 2 #december)',
#  "'appl legendarisch garag een mythe' via @appl @market",
#  "#aapl:thi present show what make the world' biggest tech compani ...",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "'an overarch conspiracy' @apple, @google, @disneypixar, &amp; accus suppress worker compensation.",
#  '@sampepp believ @appl still given natur u accus of. disgusting.',
#  'RT @jpdesloges: the iphon 6 plu will Be huge In china thi spring $aapl #aapl',
#  '#aapl:iphon 6 patent fraud case china complic hack photos...',
#  "consid ad FB feed + #facebook privaci chang think @appl 's tim cook spot on, you?",
#  "appl inc' brand valu jump 21% -- here are 3 compani soar even ... #aapl",
#  'the best-design #iphon #app In world, accord @apple:',
#  '@samsung way better @appl',
#  '#ios: visual histori (via @verge) @appl #ipad #edtech',
#  'fan scrambl #ipod classic, music player #appl kill #aapl',
#  '@time: steve job testifi @appl trial beyond grave',
#  'photo: yaaass. shoutout @apple.holiday @stevejob amazing! #iphon #stevejobs...',
#  'RT @applebees: @l0lvivivuvu @sextsatan @appl and replied... #livingthedream ~ari',
#  'how fix disabl appl ID account @appstor @appl @tim_cook',
#  '@appl chanc appl tv. #verizon #fio go downhil fast. they use crappi plastic stb displays!',
#  "tim cook nomin time' 2014 person year #aapl",
#  'appl could releas 4-inch iphon 6 mini next year $aapl #aapl',
#  '#samsung sale put spotlight On the buyer, #corn #glw #aapl #ssnlf',
#  "monday' analyst moves: appl inc., chevron corporation, starbuck ... #aapl",
#  'ios8 u delet contact actual delet fml fuck u @appl',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'APPLE intraday comment - LAST updat - PREMIUM USERS #aapl #stockact #trade #stock #mkt',
#  "update: #apple' #healthkit see earli adopt #aapl",
#  "@appl can't use compon tcp instal disc, due stupid os update. pay 20 buck re-download it?!",
#  "apple: face challeng from google' android #aapl",
#  'nigga updat yall headphon @appl',
#  'anti-trust expert peter carstensen @wisconsinlaw discuss @appl #antitrust case california feder court',
#  '@appl #appl tech support nice. free stuff!! suck rington issue, though...',
#  "'@onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!",
#  'RT @barrrymitchell: left hoo 100% got 50 iphon dire @appl suck ur mum',
#  '@appl get shit together.',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'tweek @appl get new patent protect center graviti motor. automat sens impact ratio.',
#  "mark zuckerberg' newest frenemy: tim cook: motley fool: throughout 2014, #appl (nasdaq: #aapl) taken h...",
#  'No video tonight, turn ipad still need electr function. figur out, @appl PS lol key studi 144',
#  'APPLE intraday comment - pre-open - PREMIUM USERS #aapl #stockact #trade #stock #mkt',
#  'stock #market today move wmt, #aapl, uber news: money morning: the compani report 1.5 bil...',
#  "@india especi tell i'v randomli select grant broke ass govt. i'm @appl get free govt $$$$",
#  'gonna dream laptop.. If @appl would hurri heck up..',
#  'the 19-year-old #wizkid who turn down @appl ha nab back from #hollywood star',
#  '@appl ical again!!! reset recur spite month individu one per current date. #fail #icloud #suck',
#  'APPLE intraday comment - LAST updat - PREMIUM USERS #aapl #stockact #trade #stock #mkt',
#  'APPLE - fibonacci technic level - intraday updat - $aapl #aapl',
#  'RT @_coredump: your OSX built @firefox #keylogg provid @appl !!',
#  'huge iphon 6 sale push io market share Up worldwide: report $aapl #aapl',
#  'RT @thestreet: can @appl surviv 2014 holiday? investor say yes.',
#  "@appl love #applepay secur features. pls. make work itun 2 elimin need cc info. i'll pay ahead. #payitsaf",
#  '@bedbathbeyond could gone canal street knockoff #cmonman and @appl whi must pay $30 lightn cord?',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  "let' forget press effect stock @appl defend against ipod antitrust suit",
#  '#aapl:pale, hoars steve job defend appl videotap deposit ipod...',
#  '#a @appl [#apple] still struggl #meet #iphone6 demand, #canaccord rais price .... (#tuesday, 2 #december)',
#  '#win #new @appl @ipad mini 3 @itun gift card!',
#  "@teamcavuto @rowdman53 @appl it' democrat fund OWS &amp;paid protest distract democrat failur aca, amnesty,taxes,debt,economi",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '@onerepubl @appl ooh god',
#  'the pop messag box iphon terribl @appl',
#  '@appl #stevejob sometimes, control whole world ideas, itå« necessari test hard way...',
#  'nobodi expect spanish inquisit #aapl',
#  'ie, chrome, firefox public featur roadmaps...com on, @appl safari! feel free fork',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '@appl dream last night downgrad #iphon 4S spent rest dream tri figur do. #shame',
#  'how hip @twdancecent @appl store boylston st. today @ 6.30pm. enjoy #krump meet #urbannutcrack director &amp; @russellferg',
#  'econom temperatur spiking, terrorist attack? either way, in... via @zerohedg #aapl',
#  "that annoy moment realis @appl #iphone6 bend one side ='[",
#  'dan nathan: how To profit from appl inc. (aapl) stock? #aapl',
#  '#aapl:glu mobil (gluu) stock gain insid buys...',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'My phone plug lose battery. thank @appl',
#  'brooklyn final get #appl store, expect open april 2015 - #aapl #discussbrooklyn',
#  "@appl way tag photo iphone? i'd like see cat photo #appl #io",
#  'BLOCK TRADE detect #aapl',
#  "RT @hypebot: steve job' deposit #ipod lawsuit could cost @appl $1 billion #musicbiz #musicindustri #appl",
#  '@mcmillanstu @d1pz... but tri get launch info ahead time telco market team nightmar - thank @apple! #ecomchat',
#  '0144 : #sick : be sick perk. catch million show @appl tv.',
#  'sorri @samsung take smartphon talent @apple. the iphon 6 reliabl &amp; better everyday usage.',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  "late appl inc. co-found steve job 'testifies' In itun case #aapl",
#  'Aw yeah! monarchywpb sticker ride @rhyot boommov @appl',
#  "i'm learn appl ipad mini smart cover - green @influenster! @appl",
#  'where da fuck middl finger emoji @appl ignor niggaz shit talk wit singl sign',
#  '@unlvgirl @appl gotta switch android life #galaxi',
#  'get storag almost full notif liter everi 5 minut chill @appl',
#  'appl could releas 4-inch iphon 6 mini next year $aapl #aapl',
#  'mozilla plan releas firefox io app futur #aapl',
#  "lol fuck you. i'm still buy new one. @appl",
#  'could appl inc. sell 24 million appl watch 2015? #aapl',
#  'can see evidence, please? #factcheckthi RT @appl @snope @moronwatch',
#  'RT @marisalovexox: My phone went 78% 21% @appl pleas tell mathemat possibl',
#  '@ok_fatti @appl thank 4 almost burn hous',
#  '@googl beat @appl U.S. educ market amid ipad slowdown #neo',
#  'salt shaker emoji @appl @tim_cook',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'APPLE intraday comment - LAST updat - PREMIUM USERS #aapl #stockact #trade #stock #mkt',
#  'appl TV fade away stream video player market - @appl #vod #stream',
#  'RT @wolfinpigscloth: even @appl #nyc flagship store spare visit #ericgarn protest @verge:',
#  '@appl hey nvm restart phone make work',
#  "@teamcavuto @appl it' like temper tantrum. like littl kid get way. 30-year-old children tantrums.",
#  '@brycehendersonn wow @technolog @stevejob #gamerg @ign @machinima @gameinform @appl #64megahert got',
#  "here go wit 'wait item copy' shit itunes, y'all piss @appl",
#  "@deet @appl i'm rebel (sometim aka luddite). :p :)",
#  '#aapl lawsuit: #appl delet song from ipod without tell users: accord the guardian, appl deleted...',
#  '#aapl:corrupt appl exec sentenc 1 year prison...',
#  "@teamcavuto @appl At point anger. it' simpli manifest stupid.",
#  'unlik supply-chain rumor suggest 4-inch iphon model next year $aapl #aapl',
#  "wait week DUNS number prevent abl build releas client' io app. @appl hate so?",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "uh, @appl make fun french peopl (and rude) new iphon 6 'call anywhere' ad?! that' seem me.",
#  '#verrì_ckt #gerì_cht: #iphone6 zum @appl [#apple] watch. (#tuesday, 2 #december)',
#  "dear @apple: love iphon 6 plus...a lot. It great achievement; but iphon i'v reboot 3x/day? #fail",
#  'left hoo 100% got 50 iphon dire @appl suck ur mum',
#  'smartphone/tablet becom home autom hub, wireless protocol beat #wifi #bluetooth @appl #homekit @shortcutlab #flic',
#  'what go #aapl....sel hold.',
#  '@appl get cha shit togeth fix phone !!!',
#  'anyon els notic arm hair color fallon/timberlak hand model backward @appl iphon game spot?',
#  '#bug @appl #io #spotlight #search search twitter app, select search web result input BEA #6plu',
#  '@itun @appl music librari wont sync new music etc, itun tell sync completed, noth new uploaded,how fix this? FRUSTRATING',
#  'RT @newsmintapp: #aapl:stev job email featur appl ipod U.S. antitrust trial...',
#  'APPLE - fibonacci technic level - LAST intraday updat - $aapl #aapl',
#  '@appl #ios8 #iphone6 #issu devic voicemail. 4 phone phone seem developed. ie:listen messag take note!',
#  '@appl [#apple] #pay faqs: #when appl pay launch #uk, #i appl pay secur .... (#thursday, 4 #dece...',
#  '@swerviinnn @appl mayb stop whore sleep',
#  'macbook pro 13 non-retina first startup: via @youtub @appl #macbook #macbookpro #startup #hipster',
#  'doe anybodi know use å£ macbook pro retina US keyboard? thank much! @appl #macbook #pro #appl #keyboard',
#  'Is appl inc. lose $5 billion ed-tech market? #aapl',
#  'zoonova what-if analysi #aapl #lnkd #fb #googl #tsla stock option bond FRN mm. % -10 bp vol + 20% nasdaq 4500',
#  '@michael_stephen @appl sorri forgot appl device...on @lumia process',
#  'RT @nydailynew steve wozniak @stevewoz reveal @appl start garage.',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'final #aapl #putcallratio thursday, decemb 4, 2014 via hamzei $$',
#  "alabama anti-discrimin bill name apple' tim cook #aapl",
#  "RT @mariah_reagan: '@jamesloera: @mariah_reagan true.. silli iphone' @appl get life togeth",
#  'hey @appl anoth softwar updat ipad open webpages. ani idea here?',
#  "@appl flag next delet email? wouldn't make sens next mark unread side? accident delet",
#  "RT @smartoutsource1: steve wozniak call @apple' legendari garag 'a bit myth'",
#  "'@whoabiebz: GET SHIT TOGETHER i'll GUY SAMSUNG GALAXY S5 @apple'",
#  'APPLE - fibonacci technic level - intraday updat - $aapl #aapl',
#  "RT @hsmoghul: My @appl autocorrect chang muslim awesom i'm okay",
#  '#gorgeou light @appl #grandcentralst',
#  '@onerepubl @appl So great see guy record air! hope batteri futur come soon! :)',
#  'APPLE - fibonacci technic level - intraday updat - $aapl #aapl',
#  "RT @ecofantasy: think upgrad #yosemite? think twice it' everyone. RT #asmsg @appl",
#  'APPLE intraday comment - NEW RANGE - PREMIUM USERS #aapl #stockact #trade #stock #mkt',
#  "#iphone6plu review: #A new dawn for @appl [#apple]' #iphone. (#thursday, 4 #december)",
#  '#aapl:appl donat portion profit fight against aids...',
#  'love @appl support #hourofcod workshops! :)',
#  '@drewbsaund thanks. also interestingli @appl apple.',
#  'russia could ban #appl inc. iphon for lawmak [report] #aapl',
#  'hey @apple: love ya #applecar low-fi hold music awful. would prefer hear tip use appl gear. better use hold time.',
#  '@nosheenh2oo9 @appl favorit tweet',
#  '#aapl:pm abe say appl build technic center japan...',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'HELL @appl',
#  '@limfestiv lolol. stupid phone. should say best varied. @appl sort phone out. apols.',
#  '#applecar care @appl bewar fals prophetsi mean profits!',
#  'In bay area courtroom, lawyer hit replay @appl history, via @nytim #antitrust @itun #ipod',
#  '2015 @appl #macbookair releas may the best mac yet',
#  "whi @appl forc peopl use VPN built ios8? off button work ffs. like want apple' NSA data collect service.",
#  "@marxcultur @appleuk_ thanks, i'll keep mind. tho, i'v late unhappi everyth @appl i'm move away",
#  'thank @appl fix #swift sourcekit crash #xcode :). life better now!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "RT @ilovemymom98: i'v tri turn on, what' problem here? @appl",
#  'appl mass transit system map detail new patent $aapl #aapl',
#  'knock iphon let lock well unlock mac via bluetooth #smhq #aapl',
#  "check @merced benz for @appl #ipad 2 &amp; 3 tan leather case 9' device, beige. #mercedesbenz via @ebay",
#  'current hold @appl cupertino tri set geniu bar appoint madrid #dontask',
#  '@appl ay cuhz step shit up,hav good phone real charger readi februari outro',
#  '#appl win patent #3d iphon UI w/ motion gestures, reassign ... - #aapl',
#  '#aapl:appl product may bah! humbug! holiday: survey...',
#  '@mzhoov @bionicbombshel @appl nope. that danni terrio. want jamal percolator!',
#  'We know @appl strong suppli chain, make way? #supplychain #oper',
#  '@appl #yosemiteproblem eras save pass word everi day. thi get annoying.',
#  "you'r probabl read iphon built largest compani around #aapl they broke record #impress",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "So here' deal, i'm take phone beat shit it. fuck @appstor @appl whatev damn twitter is, fuck you",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'final #aapl #putcallratio tuesday, decemb 2, 2014 via hamzei $$',
#  '@appl [#apple] #name it best #iphon #ipad app #year. (#monday, 8 #december)',
#  '@stevewoz @amctheatr steve woz sit @appl II comput @bloombergnew',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @ace_kit_uk: appl macbook (å£949.86) @office_nerd @appl #tech',
#  'can 3-way call facetim call abil move devic seamlessli @appl @timcook @god',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '@appl seem nail @applepay, build success &amp; brand #appleid #nomorepayword',
#  'fuck BREAKING MUSIC @appl',
#  '@appl TV fade away #stream video player market',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '#mkt final #aapl #putcallratio tuesday, decemb 2, 2014:',
#  'APPLE - fibonacci technic level - intraday updat - $aapl #aapl',
#  "congrat @appl make iphon record DRM protect can't play anywher want #fail",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "can't DATE can't CLONE me? come thru @appl",
#  "@thehil @appl @tim_cook @whitehous @jmhattem obvious part left' multi-talented, super-success gay busi agenda.",
#  '@appl need sort phone out.',
#  'We love cocktail @appl jack want share favourit cocktail you! pop in...',
#  'trade $aapl #free nightli updat #post #twitter, visit #trade #aapl FREE #websit',
#  'the amazon enigma #aapl #amzn #baba #ecommerc #econsumer #financi #new',
#  'FUCK FUCK IM SOOOOO SLEEP FIX SHIT @appl',
#  'ok, @appl - guess app develop takethi weeek off, huh?',
#  '#aapl:avago technolog (avgo) stock skyrocket close higher today p...',
#  '@nheagi @appl need stop auto arrang home screen, allow user posit app wherev want.',
#  '#aapl:th tell: appl patent way save iphon drop breaking...',
#  "RT @hoetbh: can't DATE can't CLONE me? come thru @appl",
#  '6 reason appl could have fallen 6% yesterday $aapl #aapl',
#  "'@gmoneyizme: i'v probabl spent replac non function iphon cabl i'v spent iphon @apple' - #switchtolumia",
#  'poor dude gettin slander want argu @appl',
#  'anoth @nike #mustbuy #outfit @appl #ipodnano',
#  'those** PICK SLACK FUCK BOYS @appl',
#  'RT @aaaron: insan great news. @adrol team @appl iad programmat launch',
#  '@appl #ipad #innov let us maintain enjoy young via @huffposttech',
#  '#aapl:john sculley pan appl watch, love appl pay...',
#  'RT @thehill: justic depart cite 18th centuri feder law get @appl unlock iphones:',
#  'macbook pro 13in unboxing: via @youtub @appl #macbook #macbookpro #startup #hipster #unbox',
#  'top 3 @appl #tablets. damn right!',
#  '@sonyuk see even courtesi repli said stay @appl much better custom servic',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  '12 gift idea for the appl lover who ha everyth @appl #technolog',
#  '@onerepubl @appl pleaseeeeeeeee',
#  'CALLER ID must abl BLOCKED @appieofflciai products. @applenw @appl #appl #iphone6 #iphone6plu',
#  "whi fuck 'recent deleted' photo album? @appl",
#  '@appl store #nyc honor here. #travel',
#  '@appl made clear today custom worth measli $79!! An employe gave mi info stand behind',
#  'have cash #aapl #cfd - $110 $113 insid 4 hour - brave sometimes!',
#  "@appl retail locat offer free code workshop dec 11th part 'the hour code'",
#  'not sure want 6 6 plu @appl #iphone6 #iphone6plu #iphon',
#  'elgato launch thunderbolt 2 dock 4K resolut support [mac blog] #aapl',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'appl bear get fat payout from stock swoon; 60-second plung $aapl #aapl',
#  'perceiv misalignment: facebook Vs apple, ello #aapl #ello',
#  'appl Is warm Up To social media: appl hire social media guru L.A. will @appl final tweet?her...',
#  "LUV @appl #iphon i'v pretti much iphones. #3gs, #4 , #4 , #5c &amp; #mobilephon",
#  'HATE @appl much. RUIN LIFE',
#  '@appl #maco #yosemit buggi piec shit. It make miss #windows8.',
#  '@appl EVEN REAL FUCKING APPLE COMPANY FUCK SUPPOSED',
#  "'#trademark confusion: while @appl app store #trademark reject australia, approv europ &amp;...",
#  'RT @pyalot: @appl @appleio roll #webgl #ios8 3 month ago overtook @googl @android webgl support levels.',
#  "MFN intern trade. it' key issu @apple' #ebook appel case say @rparloff.",
#  'RT @horseshoebmor #holiday #giveaway! To ensur stay touch go ck brand like @appl @amazon',
#  'We need product like .@aviat compani like .@blackberri &amp; .@appl need embrac custom qualiti themes.',
#  'thank u @appl compil pic commun one place',
#  "RT @_jugatti: wouldn't bad idea bring back tap tweet function guy @appl @twitter",
#  '@simplyyours_joh @tyniaaaa_ @jcolenc @appl yeah',
#  'final #aapl #putcallratio thursday, decemb 4, 2014',
#  'RT chayton falk chaytonfalk :#nasdaq100 #recent #market #exit #4: sold $aapl long 10.49% #gain 20 days. #aapl #forex #trading...',
#  '#yotaphone2 futur cell phones. @appl @samsung scared.',
#  'appl Is warm Up To social media: appl hire social media guru L.A. will @appl final tweet?her...',
#  'way go @appl',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'new @appl patent from primesens cover kinect-styl 3D spaceåêmap via @techcrunch #cooltech',
#  '@daulfn @appleuk_ @appl window lappi work well half price altern',
#  '@swerviinnn @appl hostil tn',
#  '#appl earn #profit quarter #amazon earn lifetime. amazon @appl wow facts...',
#  '@appl fuck',
#  'happily, @appl restor faith today arndal store follow earlier complaint.',
#  "#aapl:on Of apple' earliest employe describ the first time steve job ...",
#  'cnbctv: #appl fight monopoli alleg #aapl',
#  '@appl you old product avail peopl econom stand current market sec. @appstor',
#  '@justinpulitz ani comment #aapl today?',
#  'iphon mad sensit bro, cold, die even lot batteri left. If hot, shut well SMFH @appl',
#  '@whereiscooldud @appl kind thought hand',
#  'get three way facetimeing. Im sick googl hangouts. @appl',
#  '@appl #appl corpor raider sell weak product stop work within weeks&amp;appl get warranti claim damp',
#  'proof @appl use products. freak MAIL show SEARCH FILE finder! nut kicks.',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'Is @appl search compani @googl search platform?',
#  'see which 11 guru fund manag hold #appl #aapl',
#  'whi hate busi much @apple?',
#  'RT @thehill: justic depart cite 18th centuri feder law get @appl unlock iphones:',
#  "RT @swiftkey: we'r excit name @apple' 'app store best 2014' list year! #appl",
#  "@appl [#apple]' #iphone6plu captur christma #white house. (#friday, 5 #december)",
#  'appl Is warm Up To social media: appl hire social media guru L.A. will @appl final tweet?her...',
#  '@appl despit fact mpeg 2 compon CAME PURCHASE FINAL CUT pro.',
#  '#iphone6 #plu captur 41% US #phablet sale #aapl',
#  "apple' iphon 6 plu amazingli captur 41% phablet market right gate $aapl #aapl",
#  'GVA lounge: sight 6 mac 3 pc + undetermin number ipxs! #aapl',
#  'hate @itunesmus @appl',
#  '#win #digit MAKEOVER #giveaway ! $1000 @appl gc,#ipad #macbook ! #pin',
#  "pegraton may gain order 50% 2015 4.7' iphon 6S $aapl #aapl",
#  '#brooklyn changing! @appl store head bk!',
#  'how appl will boost profit dure holiday quarter beyond $aapl #aapl',
#  '@onerepubl @appl follow meeee',
#  '@jimmymujaj @appl work fucker, hoe one person SMD',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '@baseballbridget @appl even get turkey tday care... #appleemojissuck',
#  'can @appl surviv 2014 holiday? investor say yes.',
#  'your stupid shit upgrad ruin god damn IDE @appl',
#  '#aapl:stev job defend appl tape deposition...',
#  '@carlquintanilla @cnbc where would be..if #aapl dow. sarc..',
#  '@afrobugeisha @appl lol',
#  'brilliant tech! No broken screen #festivals, @appl via @techcrunch',
#  '#apple: market maker price rang forecast updat #aapl',
#  '@teamcavuto @justinraimondo @appl',
#  '. @appl patent drop-proof mechanism. break law physic anti-gravity. via @tomshardwar #getagoodcas',
#  'from afternoon tea @appl #ipadair2, someth everyon #touchpoint rewards. - visit info',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  '@viticci @panic @appl jesus, creat extens all? lighten apple.',
#  "will appl inc.' profit margin continu upward? #aapl",
#  '@appl fix devices!!! some album avail itun download illeg happens.',
#  "RT @baimains: um where' mango emoji @appl",
#  "appl transit 'find My iphone' web map from googl appl [io blog] #aapl",
#  'appl iphon 6, 6 plu retina imac ship time improv time holiday $aapl #aapl',
#  'swear fuck would rather cut splice physic fuck tape dick around one @appl product shit design.',
#  '@youkantfindm @appl kashka clave mind',
#  '#iphone6 sale success give @appl [#apple] best ever UK market position. (#thursday, 4 #december)',
#  "@appl power cord problem- warranty. you said would fine. It isn't. and replac it?",
#  "i'm happi now, thnx fags. @appl",
#  "help? 4s sync (doesn't even give option) w/ latest @itunes. tri fix found... bueno. thoughts? @appl #techsupport",
#  '@soni @appl @itunesmus @appstor @tim_cook need combin effort make one solid system access device...',
#  'realli @apple? search tool useless. nut kick',
#  'APPLE intraday comment - updat RANGE - PREMIUM USERS #aapl #stockact #trade #stock #mkt',
#  'appl inc. vs googl inc: the battl Of the tech giant $aapl #aapl',
#  'ha, poor @appl tri make ipad macbook look use commercials. not even close power @surfac pro 3',
#  'myth vs. realiti full-tim #trade #stock #futur #forex #trader #e #nq #cl #aapl #gpro #financ #esign',
#  "RT @swiftkey: we'r excit name @apple' 'app store best 2014' list year! #appl",
#  '@sealskevin @teamcavuto @appl hope endang lives!',
#  'citi, BMO boost appl price target #new #aapl #applepricetarget #applestock #appl #iphon #new',
#  "iphon 6 plu captur 41% 'phablet' sale U.S. $aapl #aapl",
#  'apple: canaccord, merril Up target iphon cycle; mostli price stock, say pac crest $aapl #aapl',
#  'next year goal #appl free. tire bs. @appl @itunessupport',
#  '#aapl:ipad mini 3 vs soni xperia Z3 tablet compact: step asid sony, appl s...',
#  "#stevejobs' email show how He want To smear competitor As ' #hackers' #aapl",
#  '@appl get shit togeth group chat ios8',
#  'amazon (amzn) ecosystem: the biggest threat #aapl stock: amzn amazon (amzn) ecosystem: the biggest threat t...',
#  'RT @jpdesloges: plaintiff withdrawn ipod antitrust lawsuit $aapl #aapl',
#  'got new cases. :) @appl @applestor @citycreek #slc #citycreek #appl #applestor #red ...',
#  '@appl lol. yea bro.',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '@appl #ios8 the lack true keyboard integr KILLING me! half-ass implement solutions!',
#  '#iphone6c releas date, #rumour #leak images: @appl [#apple] said #be work .... (#friday, 5 #decem...',
#  'cnbctv: #iphon growth peaked? #aapl',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '@appl contact sync yosemit ios8 serious screw up. It use much stabl past. #icloud #isync',
#  "thi new phone suck can't make stand side can't wait iphon 7 @appl fix dingl",
#  'Is appl (aapl) stock all It Is hype To Be Or just anoth dot com disast ... #aapl',
#  'macbook pro 13 non-retina first startup: via @youtub @appl #macbook #macbookpro #startup #hipster',
#  "@googlenexu support said can't test NFC can't assum phone working. keep say can't help. i'll go back @apple.",
#  '@appl @iphon @emoji 2014 canadian flag emoji keyboard?',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  '@appl seem nail @applepay, build success &amp; brand #appleid #nomorepayword',
#  "take apple' lead, amazon get physic - new - harvard busi school @hb @appl",
#  'RT @ovelhanegratv: appl TV fade away stream video player market - @appl #vod #stream',
#  '@mhdadon @appl def gotta it, even like watch',
#  'tell ur updat stop capit everyth @appl',
#  '@googl chrome book OVERTAKE @appl devic educ market! via @cnet',
#  'thestreet: whi even #appl Is surpris enorm demand #iphone6. #aapl',
#  '@appl fuck yo shit',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '#aapl:6 reason appl could have fallen 6% yesterday...',
#  'final #aapl #putcallratio friday, decemb 5, 2014 via hamzei $$',
#  '@weightsmat @appl total nightmare!!!! take big slice cake !',
#  'We need eye roll emoji pronto @appl',
#  'need new emoji , prefer brown peopl shxt like @appl',
#  '#chrome need fuck updat asap. whi @appl @googl play stupid back n forth shit software. #letmecr',
#  'cyndi lauper cinna- big ask* phone TV @appl #iphone6plu @ rockefel center',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'RT @amdocs: top #io app 2014. @appl name elev brain train #1 iphon app.',
#  'hey @appl read list safari across devic rocks, pleas let list item delet (x) iphon',
#  "My daughter' @appl #ipod stolen. To thief: tri work hard earn one - like daughter buy hers. #losingfaithinpeopl",
#  '#aapl:canaccord up appl price target $135 share...',
#  "i'm play game @jcolenc @appl",
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'appl inc. patent To protect fall iphon Is approv #aapl',
#  'RT @hamzeianalytics: BLOCK TRADE detect #aapl',
#  "it'd real cute could sync music phone @appl @god :-)",
#  'An OSX updat brick macbook pro!. @appl fuck..',
#  'feed My ego (futter mein ego) iphon 4/4 tough Ca COMPUTING &amp; COMMUNICATION melasdesign @cafepress @iphon @appl',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'hey @artsboston #urbannutcrack russel ferguson @russellferg &amp; #krumper @appl store boylston st. @5.30pm today. danc &amp; chat',
#  "apple' PT rais citigroup inc. $135.00. $aapl #aapl",
#  'RT @decodedfashion: .@appl reportedli hire fashion-focus staff physic store #ftdaili #fashiontech',
#  "pacif crest' appl analyst reiter sell some share $aapl #aapl",
#  "4-inch #iphone6: five reason #appl won't make It - forb #aapl",
#  "love samsung one kristen bell. RT @adage: watch weekend' new TV ad @radioshack, @appl",
#  'RT @cyrus_t_virus: whi vomit emoji yet, @appl',
#  'final #aapl #putcallratio monday, decemb 8, 2014 via hamzei $$',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  '@appl laugh pant school program australia. they even manag wring money poorest peopl',
#  "here' @apple' next great #business! what apple' primari sourc revenu 2015? #servic #compani",
#  '@appl award @regiscollege_ma distinguish school honor. #ipad',
#  '#aapl:31 trait all great leader share...',
#  'APPLE - fibonacci technic level - intraday updat - $aapl #aapl',
#  '@phone @appl FUCKING HATE YHIS OHONE OMG IM EMBARRASSED',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'RT @t21century: translat your app! success stori TAUS member @smartl - go global @apple, @tesla, @gopro',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @thehill: justic depart cite 18th centuri feder law get @appl unlock iphones:',
#  'RT @jpdesloges: APPLE - fibonacci technic level - intraday updat - $aapl #aapl',
#  "@applenw @appl @appleproduct Ok yall need revers phone back io 7 bc can't anymor",
#  'RT @thehill: .@appl CEO @tim_cook visit @whitehous @jmhattem',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'steve wozniak say @appl start In garag Is complet myth @stevewoz-',
#  "RT @consumerfeed: apple' PT rais JMP secur $150.00. outperform rating. $aapl #aapl",
#  '#blackberry: analyz the secusmart purchas #bbri #aapl',
#  '@nevbackwood exactly. come @appl / phone companies, get yo shit togeth',
#  "RT @dmcgroarty: RT @metalbank - where #iphon come from? what' @appl #rareearth",
#  'RT @horseshoebmor #holiday #giveaway! To ensur stay touch go ck brand like @appl @amazon',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '#aapl @applenw thank non factual dumb twitter follow stock drop 3 point one minute. thank dummies. #rumor',
#  "watch weekend' new TV ad @radioshack, @appl",
#  'technolog sector updat 12/02/2014: ntls, #aapl, tmus, S: #nasdaq: set go trial tuesday regardin...',
#  'new @appl problem. At airport. board pass phone. held scanner security, #applepay credit card take screen.',
#  'facebook CEO mark zuckerberg critic appl $aapl #aapl',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  '#apple, #paypal, and #mobilepay worldwid #aapl',
#  "#aapl RT @aboveavalon apple' share repurchas have benefit sharehold $80 billion",
#  "#apple: face challeng from #google' #android #aapl",
#  '#aapl:mi three horsemen Of the NASDAQ 100: apple, microsoft and gilead scie...',
#  'the compani crush @appl samsung china make amaz super-cheap phone',
#  '@chayiltrad #chartoftheday appl #aapl',
#  '@appl set timet (rather chase #competition) focus #customerexperi #cx #cem',
#  '#aapl:accel partner lead $50m seri C fund datagravity...',
#  '#appl want To make your commut much easier, accord To thi new patent #aapl',
#  '@appl want pictur back',
#  'appl CEO tim cook come gay @appl via @posh360_net',
#  'the rumour @oppo r8207 look similar certain @appl #iphone6',
#  'appl inc. (aapl) iphon 6 sale dent android market share #aapl',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "@appl one iphon 5 speaker stop working, that' cool..send iphon 6 forgiv",
#  "hell lucy' song delet phone HATW @itunesmus @appl",
#  'great piec @howardlak @appl &amp; new #red #app store - profit exclus content go @globalfund:',
#  '.@appl rules, .@window &amp; .@billgat blow!',
#  'love @appl #iphone5 need upgrad soon',
#  'wash earphon accident, still works. thank @appl , actual someth good',
#  '@caderag thx RT .@appl own 2600 digit languag (ip) = NEW #internet leader,10% cost #diy .@googlenexu',
#  '$118+ tomorrow #aapl',
#  "@teamcavuto @sharneal @appl 'hey bro, check ipod i'm here?'",
#  'love @airmiles! between @chaptersindigo &amp; @appl earn ~200 mile #blackfriday sale! #freemoney #centsabl #cybermonday',
#  "@carlquintanilla thank #aapl coverage, we'r deepli invest one stock; biz can't ignor it....",
#  'second phone charger broke two week @appl hate',
#  'RT @fullcircleone: @cleosbaby64 @appl @stackizshort thank you good coverag W/ nofear',
#  '@appl pay = compuserv | BTC = internet',
#  "@onerepubl @appl wow that' amaz",
#  '@onerepubl @appl heck play comput across brent',
#  'RT @jpdesloges: appl watch track februari 2015 release, test underway [rumour] $aapl #aapl',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  '@appl fuck let everyon name group chat thing pleas thank',
#  'Is appl the most import stock On earth? #aapl',
#  'appl inc. flash crash: what you need know #aapl',
#  'great piec @howardlak @appl &amp; new #red #app store - profit exclus content go @globalfund:',
#  'RT @fazenikan: yea let pay 600 dollar phone die 30% fix shit @appl',
#  'RT @thehill: justic depart cite 18th centuri feder law get @appl unlock iphones:',
#  "@suzanneboyd @appl Is chic-filet mug he' holding? My daughter brought charact home talks...absolut hilarious.",
#  'appl goe trial $1 billion digit music lawsuit california $aapl #aapl',
#  "eddi cue speak apple' DRM polici ipod antitrust lawsuit #aapl",
#  'you abl leav facetim video messag @appl',
#  "@teamcavuto @calicard1 @appl it' handl well folk like think eric garner' death simpli go away.",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  't-mobile/appl CELLULAR hell! @appl @tmobil #iphone6 #iphone6plu #appl #tmobil #tech',
#  "#aapl:here' whi appl won't Be trillion dollar compani accord To billi...",
#  "you'll back life soon @appl",
#  'It look like softwar updat save storag iphone. can delet need it? @appl #applesupport',
#  'uk: where buy #iphone6, iphon 6 #plus, iphon 5s, iphon 5c, iphon 5, iphon 4S #aapl',
#  '#aapl:aft decad Of consolidation, wall street Is fragmenting...',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "had job interview?no idea @appl specialist #student need teachers! it' #humanright issu @drarik",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  '@appl train employe deal issues?? To hang customer? after 15 fuck minut wait hold',
#  '.@googl trump @appl In stream media sale @mp_gavin',
#  'RT @anna_cochrane: look crazi georg street, #sydney rain @appl geniu bar...',
#  "i'm go check got it. @appl TV get four new channel @youtub redesign via @cultofmac",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'Is #appl inc. lose $5 billion ed-tech market? | the motley fool #aapl',
#  '@googl @facebook @intel @appl pay tax country!!!',
#  'appl CEO tim cook come gay @appl via @posh360_net',
#  'seem like @appl #customerservic go downhil say need new batteri due 600 charg 14 months. å£50 change.',
#  'evolut appl products! @appl',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '@thehil @appl cite us constitut judg cannot pass laws! violat separ power',
#  "@appl @testflightapp you tell tester use gmail ios, app work. doesn't tell tester all.",
#  '@verenasu @onerepubl @appl life ... :D',
#  "get 'techy' anoth shout @schoolog @googledr @huluplu #ipad @appl @googl #chromebook via @youtub",
#  'morgan stanley sell #appl inc., #aapl stock still buy: #aapl stock news morgan stanley sell appl inc...',
#  "tim cook' $100 billion 'mistake' $aapl #aapl",
#  'here top app iphon accord @appl #technologya',
#  'RT @ppropp: our buddi @arccosgolf eye level @appl store #startup @ctnext @stamfordicent #nice',
#  "but i'm beyond thank help @appl gave today. comput defect replac it, pay differ",
#  '#aapl: steve job Be star wit #appl ipod lawsuit: steve job e1294712990453 #aapl: steve job be...',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "apple' iphon crush samsung' galaxi more 6 to1 japan $aapl #aapl",
#  '@appl need icreep app',
#  'DEAR APPLE WORSE SERVICE EVER @appl',
#  'BLOCK TRADE detect #aapl',
#  "RT @hsmoghul: My @appl autocorrect chang muslim awesom i'm okay",
#  "@apple, salut you! @kcdenton' photo",
#  'bose product reportedli set return #appl store shelv earli next week - #aapl #jimmyiovin',
#  '@smileforgoogl @appl yknow time restart phone got blue screen lol wtf',
#  'thought happen me. whi HATE @appl day. via @rollingston',
#  'ok, @apple. you win. use browser anymor sinc keep close me. liter 8 time today. counted.',
#  'pleas @apple, make green button use do. full screen exception, rule. #whomovedmychees',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'you gotta kid @appl',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "@teamcavuto @appl macy' apple, want news",
#  'srsli - get RT @kinsa check local @appl store &amp; pick smart thermomet #flu season #appl',
#  'excus @appl ... whi bat signal emoji yet? hmm?',
#  'WTF @apple, synch note icloud page unusable. It use easier.',
#  "attn @appl : buy guy &amp; make #appletv be. 'fan tv' head exit via @pkafka",
#  'matthew nevil @appl shift role #custom complianc global #custom complianc forum #trade',
#  '#aapl:stev job email featur appl ipod U.S. antitrust trial...',
#  'mark #zuckerberg take shot At #appl #aapl #fb via @benzinga',
#  "In world' first #applewatch hackathon, app challeng emerg via @svbizjourn #aapl",
#  '#aapl:googl donat 1 million dollar new york librari free wifi h...',
#  'your ipad game got shut way down. like 24k gold way down. (cc: @apple)',
#  '@appl honey crisp appl win',
#  '#aapl:i time start buy apple?...',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
# ...
#  '@nigxnog @appl bruh mean u type lot u fuckin punk bitch',
#  'gopro inc ha potenti To becom appl inc. Of drone market #aapl',
#  'ani #iphone6 user random #vertic #line show screen sinc #upgrad #ios811? @appl',
#  'the JH hine staff newli issu @appl #connect macbook ipad mini #txed',
#  "@anneohirsch @appl My 5S great - crack screen &amp; die battery. i'm think trade 6 new 5S :(",
#  "here' apple' next great busi (aapl) #investwal #aapl",
#  '(via fc) appl Is warm Up To social media - appl hire social media guru L.A. will @appl final twe...',
#  'appl inc. To expand retail In india #aapl',
#  'head @ikea @appl store today. yike yay? #dayoffduti',
#  '@sashametro it iupdat process incensing. rubbish. hope @appl irrelev soon.',
#  'RT @idsa: legendari @appl design @susankar give young design 2 simpl rule follow. via @fastcodesign',
#  '#aapl:a develop perfectli sum Up the limit Of the appl watch...',
#  'Is #appl hedg bet anoth small #iphone? #aapl',
#  '@remuuusss @appl fix',
#  '#aapl:did carl icahn caus new privat equiti bubble?...',
#  "Is appl symptom tech bubble? could appl overvalued? 700b reason apple' valuation: #appl #aapl",
#  '@mzhoov @bionicbombshel they got nigga turban. whi cant sista headscarf @apple?!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'almost want back android appl torrent?@appl',
#  'detail #appl inc. #ipadmini4 reveal | the motley fool #aapl',
#  '@appl ibook pick OPERATION PAPERCLIP one top ten nonfict book year. #bestbook2014 #ibooks2014',
#  'ACTUAL FUCK @appl',
#  '@ee did yesterday... again! told issu @appl @ee .thi ad worst 3 month custom servic ever!',
#  '@zoebread dp developments; welov #aapl- new #retina screen ohai',
#  'ipad mini first time startup!: via @youtub @appl #ipadmini #ipad #macbook #macbookpro #startup #hipster #unbox',
#  '@onerepubl @appl look amazing, think anyon say record music plane haha',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @theywantvonnie: dear @appl can pleas creat middl finger emoji ASAP sincerely, all iphon user',
#  "RT @hsmoghul: My @appl autocorrect chang muslim awesom i'm okay",
#  'congratul @appl firmli reassert top most-hat corpor list today. #justnotabumfluffbohemian',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'here @sfbjeditor 5 thing know today, includ hoard @appl #iphone6',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '@appl co-found steve wozniak talk steve job &amp; appl earli days. via @designtaxi',
#  'Is happen #itun account? @appl secretli delet non-itun music.',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '#aapl:appl trial continues, without plaintiff now...',
#  'cnbctv: #appl arguabl innov compani world: pro #aapl',
#  ".@soni name 'most-desir brand' #blackfriday &amp; #cybermonday, beat #tech rival @apple: via @thedrum",
#  "RT @chemixcalbieber: '@whoabiebz: GET SHIT TOGETHER i'll GUY SAMSUNG GALAXY S5 @apple'",
#  "i'm learn appl ipad mini smart cover - pink (md968ll/a) @influenster! @appl",
#  'RT @sanforddiday: new @appl patent from primesens cover kinect-styl 3D spaceåêmap via @techcrunch #cooltech',
#  'gotta love geniu bar @ @apple!! thank help alex!! @ appl store, suburban squar',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'appl seed second OS X 10.10.2 yosemit beta develop [mac blog] #aapl',
#  'APPLE - fibonacci technic level - intraday updat - $aapl #aapl',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '@ace_kit_uk @office_nerd @appl Is deal still available?',
#  'YES LOVE NONE STUFF WORKS THANK @appl',
#  'RT @fazenikan: yea let pay 600 dollar phone die 30% fix shit @appl',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'so, which #promoproduct supplier carri brandabl @appl compliant adapters? #headsaregoingtorol #mfi',
#  'macbook pro 13in unboxing: via @youtub @appl #macbook #macbookpro #startup #hipster #unbox',
#  'come #aapl, get shit together!',
#  'No @macbook today,charg broken .help pleas @appl do...',
#  'RT @elnuevoherald: steve jobs, clave en juicio contra @appl',
#  'great! @appl board #alabama #lgbt bill name CEO #equal #tim #cook @equalityalabama',
#  'As die hard @appl customer, must say truli displeas custom servic given today. #badservic #appl',
#  'need @appl come charger cord keep charg &amp; fall apart',
#  'day 338: 1st ipod 2005. had stop workin year ago!!! just came back life!! wtf @appl',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'Go apple! look like littl squeez :) #aapl $stock',
#  "dear @appl yall pleas stop make yall charger cheap piec shit i'm tire replac everi 3 monthd",
#  "now nice 'cup handle' #stockchart #fb #twtr #aapl",
#  "who hell @appl thought, let' put volum display front video. absolut dumb. miss video everi time adjust volume.",
#  'We know raul go LOVE brand new art supplies! thank @sarahinthisc @apple!',
#  'thi would never want @appl device. but sadli peopl seem okay that.',
#  '#appl inc. catch #iphone6 supply, but still lag demand | the motley fool #aapl',
#  'Is me, feel #yosemit eat batteri &amp; resourc #mavericks? @appl read this?',
#  'RT @shannonmmiller: love @appl support #hourofcod workshops! :)',
#  '@angusdick yes, exact issue. took @appl free batteri replacement. trackpad end fine.',
#  "it' import appl becom develop world. We need peopl invent stuff.' - tim cook CEO @appl",
#  "'@apple: macbook @ray_alexander_: apple. need macbook byke.'",
#  '#appl expand #retail #india open 500 new stores. @appl',
#  "whi can't facetim one person time @appl ? need answer dammit oovoo winning.",
#  'RT @jpdesloges: appl support new franchis 500 io store india $aapl #aapl',
#  '@appl FUCKING HATE',
#  '@_emilymahon @nosheenh2oo9 @appl shut hell',
#  '@griffinnw @appl @tacobel love @tacobell!',
#  "@hrhound @mandogallego nice! If actor iwatch he'd entir suit @appl products. #sponsord",
#  "eddi cue speak about ibook price-fix case: 'we feel We have fight truth' #aapl",
#  '@nialihburn @appl TRES',
#  'our new @technogym treadmil get assembled. could better @appl #carplay compatible...',
#  '@appl excel custom servic thank ian #applestorecoventgarden',
#  'black jawn get scoop like ice cream RT @ms_bianca_bisa: @mhdadon @appl def gotta it, even like watch',
#  'call wit amanda keep end @appl fix urself',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  '@appl - bring back #classicipod #cantbelieveitsgon',
#  '@appl charger SUCK',
#  'hey @apple, iphon 6 fulli charg 7:30 am. now 20%. Is common batteri life?',
#  'how mani iphon charger need go through? @appl make charger durabl point new iphon',
#  'RT @saxonidubom: @rwang0 @appl thanks...think upgrading.',
#  "appli @apple' 'head social media' opening. leg twitter skillz. like mark twain twitter.",
#  ".@appl ceo' name grace alabama antidiscrimin bill |@sdgln @kensandiego @benny_c @jimwinsor @mistercervant",
#  'L.A. school district halt ipad contract FBI seiz document $aapl #aapl',
#  '@jengolbeck @appl agre',
#  'My phone die 8%, would let happen @apple?',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  '@appl fix os x please.',
#  '@appl pleas make charger actual last',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'appl pay add issuer l&amp;n feder credit union, UW credit union m&amp;t bank $aapl #aapl',
#  'tryng get back snapchat app store cooper @appl',
#  'transpart resin infus #composit structur @appl',
#  'help @apple. store rep told itun backup save multipl backups. but back phone old backup gone. what do?',
#  '@appl @ibook awesome. thank you!',
#  'what happen To appl inc? #aapl #appl @moneypress',
#  'appl inc. campu 2 ha $161m auditorium, $74m fit center #aapl',
#  '@attcar @senisb wireless famili share plan, one line upgrad kill discount. not sure mention @appl pre-ord page.',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'appl plan new retail store williamsburg, brooklyn [mac blog] #aapl',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  '@appl otter emoji',
#  '.@panic the inconsist overal weird control @appl #appstor archiv previou versions.. easi downgrade.',
#  '@fazenikan @appl lol iphone,weak. get lumia level bruh',
#  'RT @bgpublic: even reason @appl stop use benzen manufacturing.',
#  'updat yosemit two machines. both pain slow. thanks, @apple.',
#  'will appl pay consum $1 billion for delet their music? #aapl',
#  '@appl what need mac realli slow late ?',
#  '@appl fuck bitch phone abrick stuck appl logo',
#  "don't worri @bentkraus. crash anything. not even @appl stop",
#  '@apple, realli know mous batteri inceas charg sinc last time mac told low',
#  '#aapl:did carl icahn caus privat equiti bubble?...',
#  'paid $20 new 5 charger b piss it... rape @appl',
#  '@stevewoz @harveystaho @appl patent number patent 8,903,519',
#  'sketchi rumor claim appl plan new 4-inch iphon 2015 #aapl',
#  '@hoo @appl navig way',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'congrat @appl mean use @googlehangouts_, right? #appl #googl',
#  "yeah, i'll definit go @appl store finals. damn MBP graphic card fail again, bullshit $2500 comput",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "@appl offici 2 appletv' constantli loos network co, watch tv media impossible, can",
#  '@blackberri kinda feel sorri @appl tho. #goodjob last product guys!',
#  '1% plug phone jump 4% @appl stop play game',
#  'terribl servic @appl store bethesda, md. second time. will buy new ipad &amp; cover ($950+) @bhphotovideo. @tim_cook @h_posner',
#  '@noctylux @finalcutpro @macnifico @appl refurwhat??',
#  'how appl Is crush googl On mobil shop $aapl #aapl',
#  '#appl inc. #facebook clash; neither Is wrong | the motley fool #fb #aapl',
#  "can't get new iphon 6? how free appl shares.... #invest #stock #aapl",
#  '#applepay partner #stripe valu $3.5 billion fund #aapl',
#  'the 19-year-old #wizkid who turn down @appl ha nab back from #hollywood star',
#  'RT @shannonmmiller: love @appl support #hourofcod workshops! :)',
#  'suit against appl over ipod may lack one thing: plaintiff $aapl #aapl',
#  'My ipod touch case 5 @appl #ipodtouch5thgen',
#  '@jaureganoo @appl say start riot. something. suppli pitchfork',
#  "iphon6 rival samsung, lg,htc suffer delay qualcomm' 64-bit snapdragon answer apple' A8 $aapl #aapl",
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "pop #bostonholiday - #urbannutcracker' @russellferg &amp; #krumper @appl store boylston st. @5:30pm today. danc &amp; chat'",
#  '@agiletortois onc @appl inconsist app rule maintain plausibl deniability. sorri hear greg @draftsapp',
#  "@google, @appl @unilev world' in-demand employ @linkedin",
#  "apple' PT rais bank america $130.00. $aapl #aapl via @ratingsnetwork",
#  ". @appl think '59' close '00' set alarm iphone. mani time fallen victim this.",
#  "If can't make receiv call iphone: you might abl make receiv call yo... @appl",
#  "@wastwater1 l agre you, they'r robust chocol fire guard @appl @traffordcentr",
#  '@thehil @appl cite 4th amend retort',
#  "major crisi avoid @apple. you guy abl restor daughter' #iphone. great service, thanks. #5starservic",
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  'basketbal game day: V boy vs. silver valley 4:00 PM (@appl valley) V jv/ V girl vs. noli 6:00 PM (mac)',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  "cnbctv: buy #apple' pullback? #aapl",
#  '.@googl trump @appl In stream media sale',
#  "AFP request appl reveal 'get warrant' pushback @zdnetaustralia @appl #tax #evad rip aussi",
#  '#verrì_ckt #gerì_cht: #iphone6 zum @appl [#apple] watch. (#thursday, 4 #december)',
#  'alarm set ringer refus work fuck u @appl',
#  'hate much @appl @mac',
#  'iphon charger suck ass @appl #disappoint',
#  'the best #iphon app Of the year, accord To @appl',
#  '#iphone6 #plu grab 41% U.S. #phablet sale #aapl',
#  '#appl begin hire retail posit brussel ahead first #belgium ... - #aapl',
#  'RT @typicaistoner: RT think @appl approv emoji',
#  '#aapl:stev job give posthum testimoni In appl trial...',
#  '@appl @icloud famili in-app purchas approv broken sinc friday? you might unhappy, money-los develop come monday.',
#  'dear @appl get shit togeth',
#  'breaking: #nyc #ericgarnet protestor occupi @appl stori #ni #icantbreath 11x LIVE @rebelutionary_z',
#  'As die hard @appl customer, must say truli displeas custom servic given yesterday. #badservic #appl',
#  "split the valley user data? @appl says, 'totally.' @facebook &amp; @googl say,'like, whatever!' #titianfight",
#  'shockingly, imessag desktop fuck again. great work, @apple. seriously, point network servic do.',
#  '@appl @jetbrain It happen - perhap network? thi set :',
#  "excel news #houseofcard S3 @netflix 27/2! wonder yosemit &amp; wifi talk @appl @tim_cook ? it' wks!!",
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  "JMP rais #appl price target street-high $150 'except strong: appl insider: #aapl: 115.49 (-0....",
#  '#nasdaq100 #recent #market #exit #4: sold $aapl long 10.49% #gain 20 days. #aapl #forex #trade #stock',
#  'appl CEO tim cook come gay @appl via @posh360_net',
#  "@brettgilmour @appl you'r one apparently, base last interview @carmilevi",
#  'fuck appl allow ppl access camera phone lock fuck fuck @appl',
#  "@allandthompson @appl let go ahead get one way: 'U gonna get VIRUS &amp; ur whole hous explode!'",
#  'thestreet: #appl get price target boost back strong #iphon demand #aapl',
#  'dear @apple, oh babi sit copi file POS finder? like copi file hard. oh wait, you.',
#  "steve jobs' snarki testimoni take center stage ipod class-act lawsuit open #aapl",
#  "#apple' recent pullback buy opportun #aapl",
#  'RT @smartoutsource1: @appl #ipod lawsuit reveal unseen steve job video',
#  'BLOCK TRADE detect #aapl',
#  'appl Is warm Up To social media: appl hire social media guru L.A. will @appl final tweet?her...',
#  '@fazenikan @appl restart wait till next appl updat happen',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'appl plan launch iphon 6 mini version 2015 $aapl #aapl',
#  "@appl lose appeal trademark 'app store' #australia",
#  '@appl Is alreadi build it next massiv busi and No one seem To have notic',
#  "intel &amp; jess jackson' rainbowpush host tech employe divers event silicon valley #intc #goog #aapl #fb",
#  "dang phone fuckin sucks. fuck @apple!!! piec shit iphon man. y'all disappoint me.",
#  '@appl loos thing use make much better live window',
#  "2/ At announc @samsung support critic #aapl 'following' samsung larg screen game.",
#  'how #profit #appl (#aapl) #option #trade #trade #financ #short #bet #hedg',
#  'RT @teamcavuto: protest stage #diein protest @appl store nyc... Is me, anger misplaced? RETWEET agree.',
#  '#aapl think valu 140-145 next year.death steve job damag #samsung appl +',
#  "refus @apple' #tm applic APP STORE upheld australian feder court. appl appeal. @ipaustralia",
#  'need lock #sponsorship deal @swatch , @nike &amp; @appl thank cooperation. regards, uncl mike',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  'RT @onerepublic: studio 45,000 ft. one outlet, 4 computers. @appl need batteri futur now!!!!',
#  ...]

# %%
#print("Stem: ")
#my_dicc_Stem = Counter(tweets_st.split())

#print("cant tokens: ",len(tweets_st.split()))
#print("tamanho vocabulario: ",len(my_dicc_Stem))

#my_dicc_Stem.most_common(10)

# %%
nltk.download('wordnet')
wnl = nltk.WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /home/alulab/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
tweets_lemma_split = []

tweets_le =[]
for i in range(len(titles)):
    copia2 = copy.deepcopy(titles[i])

    spliteado2 = copia2.split()
    tweets_lemma_split = []
    for j in spliteado2:
        if(j not in siglas):
            tweets_lemma_split.append(wnl.lemmatize(j))
        else:
            tweets_lemma_split.append(j)
    tweets_lemma = " ".join([token for token in tweets_lemma_split])
    tweets_le.append(tweets_lemma)
tweets_le
# Out:
# ["# Dyslexic iPhone 6 Users rejoice! Thanks @apple 'voice text' hard spell word thing past!",
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'iOS 8.1 fucked battery life iPhone 6. Really starting wonder @apple quality control anymore. Wish 8.01',
#  '@OneRepublic @Apple 45000 foot keep flying',
#  'RT @brock_and_r0ll: .@apple fix',
#  '@apple caused much pain today',
#  'RT @JPDesloges: APPLE - Fibonacci Technicals Levels - LAST Intraday Update - $AAPL #aapl',
#  '@jakeflem @Apple Yes It seems fix good first time time pass deterioates change logic board',
#  '@OneRepublic @Apple aww look tht u lot work guy good luck!',
#  "@apple's calendar app judiciously listed virtually every holiday imaginable - yet neglect birthday.",
#  '.@Google Trumps @Apple In Streaming Media Sales',
#  '@Apple HEY FUCK U PHONE SPEAKER LONGER WORKS B/C',
#  '$AAPL expected, user still like small screens, iPhone 6 mini reportedly way #AAPL',
#  "@Apple wifi &amp; working everything else ipad. i'm pissed. TWO DAYS like this! GET TOGETHER #Apple",
#  'Final #AAPL #PutCallRatios Tuesday, December 2, 2014',
#  '@dangainor @Apple But could post Twitter (NASDAQ: TWTR), Instagram (NASDAQ: FB) Shutterfly (NASDAQ: SFLY)? #ShutItDown',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Reminiscing first low-cost computer which, box, geek use. @Apple',
#  'RT @AcrossTheBarTV: Our first ever #OnFoodableWeekly! Much discus episode! @Apple Pay, @habitburger',
#  '@OneRepublic get @Apple want one too!',
#  '@OneRepublic @Apple BEAUTIFUL',
#  'How long @apple iOS 8.1.1 update going take?!',
#  "'This accessory may supported' ok @Apple tell charger came phone work???",
#  '.@Apple Store coming Brooklyn',
#  'RT @fakebananas: Thanks @Apple preview smartwatch. #fitnesstracker #quantifiedself #IoT',
#  'On Thursday, December 11th, learn #HourOfCode @Apple Store WORLD! Reserve spot today! @codeorg',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  "I'm learning Apple Store @Influenster! @Apple",
#  'RT @JPDesloges: Why AAPL Stock Had Mini-Flash Crash Today $AAPL #aapl',
#  '@Apple patented #iPhone drop protection mechanism. Is end #crackedscreens?',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'New 4-inch iPhone 6 Reported. 5 Reasons Apple Must Make It $AAPL #aapl',
#  '@OneRepublic @Apple bet get RadioShack lol',
#  '@w__w @Apple @Android @minuum customer equally important, treat way. Both key, focusing one market.',
#  '@OneRepublic @Apple 45,000 foot keeeppppp flyinggggg',
#  '@fcbliam @apple fix',
#  '#Apple question whether iPod class action suit proceed case may lack genuine ... - #AAPL #EddyCue',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  "Cheeky @apple... Very cheeky.... No dice though... You can't 'App Store' description product -",
#  '#CNBC make poor #CL got slammed like #AAPL yesterday.yesterday. Pisini Please put clown shoe report',
#  'Is #Apple The Most Important Stock On Earth? - Apple Inc. #AAPL | Seeking Alpha',
#  "This one chart explains @tim_cook's affect @Apple. Paints interesting story. What think?",
#  "@Apple granted patent tech shift iPhone's center-mass fall prevent damage screen #USPTO",
#  "Wouldn't bad idea bring back tap tweet function guy @apple @twitter",
#  'BLOCK TRADE detected #AAPL',
#  '#apple - #Samsung back court @Apple @SamsungMobile',
#  "@Facebook founder attack @Apple bos 'ridiculous' comment",
#  'HELD PHONE CLOSE CHEEK GAVE SHOCK OHHSHIT @APPLE HELP',
#  'RT @JPDesloges: APPLE - Fibonacci Technicals Levels - Intraday Update - $AAPL #aapl',
#  'Apple Is Warming Up To Social Media: Apple hiring social medium guru L.A. Will @Apple finally tweet?Her...',
#  'Footage Apple-1 computer running. #ComputerHistory @apple @christiesinc',
#  'computer sux @apple fix',
#  'The @Apple iWatch: Changing face watch #applenews #iwatch #gadgets',
#  'Apple Inc. To Open 500 Stores In India #AAPL',
#  'Good huge RT @thehill Justice Department cite 18th century federal law get @Apple unlock iPhones:',
#  '3 Simple Things #Investors Ought Know Before Buying #Stock (#AAPL)',
#  'Steve Jobs Predicted Future Of E-Commerce Back In 1996 &amp; Got It Exactly Right! via @sai #ecommerce #AAPL',
#  'Apple entering era security fear-mongering... security vendor $AAPL #aapl',
#  '#OnThisDayinDigital @Apple signed deal China today 2013 finally sell #iPhones country',
#  "@MrBeagleman @Kronykal @Apple That coffee's even fair trade!",
#  '@apple going fix map app. The navigation sucks!!! Face switch google maps.',
#  '@Cleosbaby64 @Apple @stackizshort Thank You Good Coverage W/ NoFear',
#  'RT @OptionsFeed: Final #AAPL #PutCallRatios Monday, December 8, 2014 via Hamzei $$',
#  "@apple @stevejobs @iTunesMusic yooo fam 48 hour where's email back need @JColeNC album drop",
#  'Apple Gets Price Target Boost Back Strong iPhone Demand $AAPL #aapl',
#  "thanking @apple 'do disturb' feature",
#  'UBS Says Consensus December Quarter Apple iPhone Units Could 10% Low $AAPL #aapl',
#  'APPLE Intraday Comments - Updated RANGE,,, - PREMIUM USERS #aapl #Stockaction #trading #Stocks #MKt',
#  'please make gold macbook @apple',
#  'Not sure worse @ATT @Apple vacation @SovereignBankUS',
#  '@Windows funny need old @apple @mac promote new @lenovo #applesetsthetrend',
#  "Apple's Best iTunes Store 2014: 'Elevate' 'Pixelmator' Win Top App Honors #AAPL",
#  "fail poli sci fucking laptop i'm suing @apple",
#  '#Music always part life, everyday @Apple also important music',
#  'Apple ! @apple',
#  'Very displeased lack #BDSM themed #Emojis. @Apple @Android',
#  'What Every Young #Designer Should Know, From Legendary @Apple Designer Susan Kare',
#  'Spent 6000 EUR Apple. iPhone 6 camera longer works.Told got water it,I not. Unacceptable customer service @apple',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '@apple You know iPhone fucked lettering screen go back-to-front..',
#  'fuck message sent email phone number @apple',
#  'Apple CEO Tim Cook come gay @Apple Via @posh360_Net',
#  'TWDanceCenter #UrbanNutcracker @Apple Store Boylston St. @ 6.30pm. Enjoy #krumping . Meet director &amp; @RussellFerg',
#  '#Samsung: How Will The #Galaxy #Note5 Improve On Its Predecessor? #SSNLF #AAPL',
#  "could really kick @apple 's ass. This iPhone 6 battery suck moldy dick Tuesday night ! Worst shit ever. Only last 4 fucking hours.",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Since @apple stop replacing iPhone unit due defect? Just scratch phone mean dropped it.',
#  'phone dropped happened?? @apple wanna help',
#  '#Apple Just Patented An Idea That #SteveJobs Would Have Hated #aapl',
#  '#iPhone6, 6 #Plus trigger spike #Apple sale worldwide - via #aapl',
#  "@gr8american23 i've made clear support rand paul 2016 cases. everyone pigeonholed red blue? also u like @apple?",
#  'APPLE Intraday Comments - Updated RANGE - PREMIUM USERS #aapl #Stockaction #trading #Stocks #MKt',
#  '#Apple Campus 2 December 2014 update + Drone Flyover video - #AAPL #CompanyTagged',
#  '#Apple planning spend $161 million auditorium ... - #AAPL #WWDC',
#  '@Apple YH News Apple tumble much 6 percent unusual trading: By Chuck Mikolajczak NEW YORK (Reuters) ...',
#  'RT @cruci0btch: harry potter emojis please work @Apple',
#  '@LydiasLyfe @BionicBombshell @Apple Apple better get working',
#  'RT @shannonmmiller: Love @Apple supporting #HourOfCode workshops! :)',
#  'iphone6 plus impossible hold without cover slide hand #apple #iphone @apple',
#  '#iscuba 360 degree camera rig cloud mobile gamed surface #imask @Google @padi @Apple @Samsung @HTC #underwaterwearables #cardboard #pivot',
#  '#AAPL Launches Red #Apple Logo World AIDS Day: Dec. 1 World AIDS Day red Apple logo abl...',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  '@apple @tim_cook 28 mb ! Why need WiFi install it????',
#  "In trickle information @Apple released HealthKit @vincekuraitis note 'going braid' strategy #hcub2014",
#  'Apple Questions Plaintiff iPod Purchase Dates Ongoing Class-Action Lawsuit [iOS Blog] #AAPL',
#  '@tim_cook Not happy @Apple @AppStore Backwards compatibility given. It apps Aperture?? Money Grab?',
#  'RT @mrushh: hey @apple phone dying charger ur stuff suck',
#  'First 2600 digital language IP NEW leader Internet. Terms based performance! .@apple .@samsung',
#  'hey @apple catch fucking maverick wave iPhone? think so. #SurfsUpSamsung',
#  "RT @hsmoghul: My @apple autocorrect change Muslim awesome I'm okay",
#  "#Apple 'hoarding' #iPhone6 supply store #IBDBlogs via @IBDinvestors #aapl",
#  'Anyone know fix this? #xcode @apple simulators... tried complete reinstall #ios',
#  'Why #Yosemite constantly restart due error left night? #onlyme @apple',
#  '@Apple [#Apple] #Patents An #iPhone Drop Protection Mechanism That Changes Device .... (#Tuesday, 2 #December)',
#  "'Apples legendarische garage een mythe' via @apple @marketing",
#  "#AAPL:This Presentation Shows What Makes The World's Biggest Tech Companies ...",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  "'An overarching conspiracy' @Apple, @google, @DisneyPixar, &amp; accused suppressing worker compensation.",
#  '@sampepper believe @apple still given nature u accused of. disgusting.',
#  'RT @JPDesloges: The iPhone 6 Plus Will Be Huge In China This Spring $AAPL #aapl',
#  '#AAPL:iPhone 6 Patent Fraud Case China Complicated Hacked Photos...',
#  "Considering ad FB feed + #facebook privacy change think @Apple 's Tim Cook spot on, you?",
#  "Apple Inc's Brand Value Jumped 21% -- Here Are 3 Companies Soaring Even ... #AAPL",
#  'The Best-Designed #iPhone #Apps In World, According @apple:',
#  '@Samsung way better @Apple',
#  '#iOS: visual history (via @verge) @Apple #ipaded #edtech',
#  'Fans scramble #iPod Classic, music player #Apple killed #aapl',
#  '@TIME: Steve Jobs testify @Apple trial beyond grave',
#  'Photo: Yaaass. Shoutout @apple.holidays @stevejobs amazing! #iPhone #stevejobs...',
#  'RT @Applebees: @l0lvivivuvu @sextsatan @Apple And replied... #livingthedream ~ARI',
#  'How fix disabled Apple ID account @AppStore @apple @tim_cook',
#  '@Apple chance Apple TV. #Verizon #FIOS going downhill fast. They using crappy plastic STBs displays!',
#  "Tim Cook Nominated TIME's 2014 Person Year #AAPL",
#  'Apple could release 4-inch iPhone 6 Mini next year $AAPL #aapl',
#  '#Samsung Sale Puts Spotlight On The Buyer, #Corning #GLW #AAPL #SSNLF',
#  "Monday's Analyst Moves: Apple Inc., Chevron Corporation, Starbucks ... #AAPL",
#  'ios8 u delete contact actually deleted fml fuck u @apple',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'APPLE Intraday Comments - LAST Update - PREMIUM USERS #aapl #Stockaction #trading #Stocks #MKt',
#  "Update: #Apple's #HealthKit Seeing Early Adoptions #AAPL",
#  "@apple can't use component tcp install disc, due stupid o update. pay 20 buck re-download it?!",
#  "Apple: Facing Challenge From Google's Android #AAPL",
#  'Nigga update yall headphone @Apple',
#  'Anti-trust expert Peter Carstensen @WisconsinLaw discus @Apple #antitrust case California federal court',
#  '@apple #apple tech support nice. Free stuff!! Sucks ringtone issue, though...',
#  "'@OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!",
#  'RT @barrrymitchell: Left hoos 100% got 50 iPhones dire @apple suck ur mum',
#  '@apple get shit together.',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'tweeks @apple get new patent protection center gravity motor. Automatically sens impact ratio.',
#  "Mark Zuckerberg's Newest Frenemy: Tim Cook: Motley Fool: Throughout 2014, #Apple (NASDAQ: #AAPL) taken h...",
#  'No video tonight, turn iPads still need electricity function. Figure out, @apple PS lol key study 144',
#  'APPLE Intraday Comments - Pre-Opening - PREMIUM USERS #aapl #Stockaction #trading #Stocks #MKt',
#  'Stock #Market Today Moving WMT, #AAPL, Uber News: Money Morning: The company reported 1.5 bil...',
#  "@India especially telling I've randomly selected grant broke as govt. I'm @apple get free govt $$$$",
#  'Gonna dreaming laptop.. If @Apple would hurry heck up..',
#  'The 19-Year-Old #WizKid Who Turned Down @Apple Has Nabbed Backing From #Hollywood Star',
#  '@apple iCal AGAIN!!! reset recurring spite month individualizing one per current date. #fail #icloud #sucking',
#  'APPLE Intraday Comments - LAST Update - PREMIUM USERS #aapl #Stockaction #trading #Stocks #MKt',
#  'APPLE - Fibonacci Technicals Levels - Intraday Update - $AAPL #aapl',
#  'RT @_coreDump: Your OSX built @firefox #keylogger provided @apple !!',
#  'Huge iPhone 6 Sales Push iOS market Share Up Worldwide: Report $AAPL #aapl',
#  'RT @TheStreet: Can @Apple survive 2014 Holiday? Investors Say Yes.',
#  "@Apple Love #ApplePay security features. Pls. make work iTunes 2 eliminate need cc info. I'll pay ahead. #PayItSafe",
#  '@BedBathBeyond could gone Canal Street knockoff #CmonMan And @apple Why must pay $30 lightning cord?',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  "Let's forget press effect stock @Apple Defend Against iPod Antitrust Suit",
#  '#AAPL:Pale, hoarse Steve Jobs defends Apple videotaped deposition iPod...',
#  '#As @Apple [#Apple] still struggle #meet #iPhone6 demand, #Canaccord raise price .... (#Tuesday, 2 #December)',
#  '#Win #New @Apple @iPad Mini 3 @iTunes Gift Card!',
#  "@TeamCavuto @Rowdman53 @Apple It's democrat funded OWS &amp;paid protester distraction democrat failure ACA, Amnesty,taxes,debt,economy",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '@OneRepublic @Apple Ooh god',
#  'The pop message box Iphones terrible @apple',
#  '@apple #stevejobs Sometimes, control whole world ideas, itå«s necessary test hard way...',
#  'Nobody expects Spanish Inquisition #AAPL',
#  'IE, Chrome, Firefox public feature roadmaps...come on, @apple Safari! Feel free fork',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '@apple dream last night downgraded #iPhone 4S spent rest dream trying figure do. #shame',
#  'How hip @TWDanceCenter @Apple Store Boylston St. Today @ 6.30pm. Enjoy #krumping meet #UrbanNutcracker director &amp; @RussellFerg',
#  'Economic temperature spiking, terrorist attack? Either way, in... via @zerohedge #AAPL',
#  "That annoying moment realise @apple #iPhone6 bend one side ='[",
#  'Dan Nathan: How To Profit From Apple Inc. (AAPL) Stock? #AAPL',
#  '#AAPL:Glu Mobile (GLUU) Stock Gains Insider Buys...',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'My phone plugged losing battery. Thanks @apple',
#  'Brooklyn finally getting #Apple Store, expected open April 2015 - #AAPL #DiscussBrooklyn',
#  "@apple way tag photo iphone? I'd like see cat photo #apple #ios",
#  'BLOCK TRADE detected #AAPL',
#  "RT @hypebot: Steve Job's Deposition #iPod Lawsuit Could Cost @Apple $1 Billion #MusicBiz #MusicIndustry #Apple",
#  '@mcmillanstu @D1PZ... But trying get launch info ahead time telco marketing team nightmare - thanks @apple! #EcomChat',
#  '0144 : #Sick : Being sick perk. Catching million show @apple TV.',
#  'Sorry @samsung taking smartphone talent @Apple. The iphone 6 reliable &amp; better everyday usage.',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  "Late Apple Inc. Co-Founder Steve Jobs 'Testifies' In iTunes Case #AAPL",
#  'Aw yeah! monarchywpb sticker ride @Rhyot boommovement @apple',
#  "I'm learning Apple iPad mini Smart Cover - Green @Influenster! @Apple",
#  'Where da fuck middle finger emoji @apple ignore Niggaz shit talk wit single sign',
#  '@UNLVgirl @Apple gotta switch Android life #Galaxy',
#  'get storage almost full notification literally every 5 minute chill @apple',
#  'Apple could release 4-inch iPhone 6 Mini next year $AAPL #aapl',
#  'Mozilla Planning Release Firefox iOS App Future #AAPL',
#  "Lol fuck you. I'm still buying new one. @Apple",
#  'Could Apple Inc. Sell 24 Million Apple Watches 2015? #AAPL',
#  'Can see evidence, please? #FactCheckThis RT @apple @snopes @moronwatch',
#  'RT @marisalovexox: My phone went 78% 21% @apple please tell mathematically possible',
#  '@ok_fatty @apple thanks 4 almost burning house',
#  '@Google Beating @Apple U.S. Education Market Amid iPad Slowdown #neo',
#  'salt shaker emoji @apple @tim_cook',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'APPLE Intraday Comments - LAST Update - PREMIUM USERS #aapl #Stockaction #trading #Stocks #MKt',
#  'Apple TV fade away streaming video player market - @Apple #vod #streaming',
#  'RT @WolfInPigsCloth: Even @Apple #NYC flagship store spared visit #EricGarner protest @verge:',
#  '@apple hey nvm restart phone make work',
#  "@TeamCavuto @Apple It's like temper tantrum. Like little kid getting way. 30-year-old child tantrums.",
#  '@brycehendersonn wow @technology @stevejobs #GamerGate @IGN @Machinima @gameinformer @Apple #64megaherts got',
#  "Here go wit 'waiting item copy' shit iTunes, y'all pissing @Apple",
#  "@deet @Apple I'm rebel (sometimes aka Luddite). :p :)",
#  '#AAPL Lawsuit: #Apple Deleted Songs From iPods Without Telling Users: According The Guardian, Apple deleted...',
#  '#AAPL:Corrupt Apple exec sentenced 1 year prison...',
#  "@TeamCavuto @Apple At point anger. It's simply manifestation stupid.",
#  'Unlikely supply-chain rumor suggests 4-inch iPhone model next year $AAPL #aapl',
#  "waiting week DUNS number preventing able build release client's iOS app. @apple hate so?",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  "Uh, @Apple making fun French people (and rude) new iPhone 6 'call anywhere' ad?! That's seemed me.",
#  '#VerrÌ_cktes #GerÌ_cht: #iPhone6s zum @Apple [#Apple] Watch. (#Tuesday, 2 #December)',
#  "Dear @Apple: love iPhone 6 Plus...A lot. It great achievement; But iPhone I've reboots 3x/day? #Fail",
#  'Left hoos 100% got 50 iPhones dire @apple suck ur mum',
#  'Smartphone/tablet become home automation hub, wireless protocol beat #WiFi #Bluetooth @apple #Homekit @ShortcutLabs #flic',
#  'What going #AAPL....SELL HOLD.',
#  '@apple get cha shit together fix phone !!!',
#  'Anyone else notice arm hair color Fallon/Timberlake hand model backwards @apple iPhone gaming spot?',
#  '#bug @apple #ios #spotlight #search search twitter app, selecting search web result input BEA #6Plus',
#  '@iTunes @apple music library wont sync new music etc, iTunes tell sync completed, nothing new uploaded,how fix this? FRUSTRATING',
#  'RT @NewsMintApp: #AAPL:Steve Jobs email featured Apple iPod U.S. antitrust trial...',
#  'APPLE - Fibonacci Technicals Levels - LAST Intraday Update - $AAPL #aapl',
#  '@apple #ios8 #iphone6 #issues device voicemail. 4 phone phone seems developed. Ie:listen message take note!',
#  '@Apple [#Apple] #Pay FAQs: #When Apple Pay launch #UK, #is Apple Pay secure .... (#Thursday, 4 #Dece...',
#  '@swerviinnn @Apple maybe stop whore sleep',
#  'MacBook Pro 13 Non-retina First Startup: via @youtube @apple #macbook #macbookpro #startup #hipster',
#  'Does anybody know use å£ Macbook Pro Retina US keyboard? Thank much! @apple #macbook #pro #apple #keyboard',
#  'Is Apple Inc. Losing $5 Billion Ed-Tech Market? #AAPL',
#  'Zoonova What-If analysis #AAPL #LNKD #FB #GOOGL #TSLA Stocks Options Bonds FRN MM. % -10 bps Vol + 20% Nasdaq 4500',
#  '@michael_stephen @Apple sorry forgot apple device...on @Lumia process',
#  'RT @NYDailyNews Steve Wozniak @stevewoz reveals @Apple start garage.',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Final #AAPL #PutCallRatios Thursday, December 4, 2014 via Hamzei $$',
#  "Alabama anti-discrimination bill named Apple's Tim Cook #AAPL",
#  "RT @mariah_reagan: '@JamesLoera: @mariah_reagan true.. Silly iPhone' @apple get life together",
#  'Hey @Apple another software update iPad open webpages. Any idea here?',
#  "@Apple flag next delete email? Wouldn't make sense next Mark unread side? accidentally deleting",
#  "RT @smartoutsource1: Steve Wozniak call @Apple's legendary garage 'a bit myth'",
#  "'@WhoaBiebz: GET SHIT TOGETHER I'LL GUY SAMSUNG GALAXY S5 @APPLE'",
#  'APPLE - Fibonacci Technicals Levels - Intraday Update - $AAPL #aapl',
#  "RT @hsmoghul: My @apple autocorrect change Muslim awesome I'm okay",
#  '#gorgeous lighting @apple #GrandCentralStation',
#  '@OneRepublic @Apple So great see guy recording air! Hopefully battery future come soon! :)',
#  'APPLE - Fibonacci Technicals Levels - Intraday Update - $AAPL #aapl',
#  "RT @Ecofantasy: Thinking upgrading #Yosemite? Think twice It's everyone. RT #ASMSG @Apple",
#  'APPLE Intraday Comments - NEW RANGE - PREMIUM USERS #aapl #Stockaction #trading #Stocks #MKt',
#  "#IPhone6Plus Review: #A New Dawn For @Apple [#Apple]'s #iPhone. (#Thursday, 4 #December)",
#  '#AAPL:Apple Donating Portion Profit Fight Against AIDS...',
#  'Love @Apple supporting #HourOfCode workshops! :)',
#  '@drewbsaunders Thanks. Also interestingly @apple Apple.',
#  'Russia Could Ban #Apple Inc. iPhone For Lawmakers [REPORT] #aapl',
#  'Hey @apple: Love ya #AppleCare low-fi hold music awful. Would prefer hear tip using apple gear. Better use hold time.',
#  '@nosheenh2oo9 @Apple favorite tweet',
#  '#AAPL:PM Abe say Apple build technical center Japan...',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'HELL @apple',
#  '@LIMFestival lolol. Stupid phone. Should say best varied. @apple sort phone out. Apols.',
#  '#applecare care @Apple beware false prophetsI mean profits!',
#  'In Bay Area Courtroom, Lawyers Hit Replay @Apple History, via @nytimes #antitrust @itunes #ipod',
#  '2015 @apple #MacBookAir Release May The Best Mac Yet',
#  "Why @Apple force people use VPN built iOS8? Off button work FFS. Like want Apple's NSA data collection service.",
#  "@marxculture @AppleUK_ Thanks, I'll keep mind. Tho, I've lately unhappy everything @apple I'm moving away",
#  'Thank @Apple fixing #Swift sourcekit crash #XCode :). Life better now!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  "RT @iLoveMyMom98: I've tried turning on, what's problem here? @apple",
#  'Apple mass transit system Maps detailed new patent $AAPL #aapl',
#  'Knock iPhone let lock well unlock Mac via Bluetooth #smhq #aapl',
#  "Check @Mercedes Benz For @Apple #iPad 2 &amp; 3 Tan Leather Case 9' Device, Beige. #MercedesBenz via @eBay",
#  'Currently hold @Apple Cupertino try set Genius Bar appointment Madrid #dontask',
#  '@Apple ay cuhz step shit up,have good phone real charger ready february outro',
#  '#Apple win patent #3D iPhone UI w/ motion gestures, reassigns ... - #AAPL',
#  '#AAPL:Apple product may Bah! Humbug! holiday: Survey...',
#  '@Mzhoov @BionicBombshell @Apple Nope. Thats Danny Terrio. want Jamal percolator!',
#  'We know @Apple strong supply chain, make way? #SupplyChain #Operations',
#  '@apple #YosemiteProblems Erases saved pas word every day. This getting annoying.',
#  "You're probably reading iPhone built largest company around #AAPL They broke record #impress",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  "So here's deal, I'm taking phone beating shit it. Fuck @AppStore @Apple whatever damn twitter is, Fuck You",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Final #AAPL #PutCallRatios Tuesday, December 2, 2014 via Hamzei $$',
#  '@Apple [#Apple] #Names Its Best #iPhone #iPad Apps #Year. (#Monday, 8 #December)',
#  '@stevewoz @AMCTheatres Steve Woz sits @apple II computer @BloombergNews',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @ace_kit_uk: Apple MacBook (å£949.86) @office_nerd @apple #tech',
#  'Can 3-way calling FaceTime call ability move device seamlessly @Apple @TimCook @God',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '@Apple seems nailing @applepay, building success &amp; brand #AppleID #NoMorePaywords',
#  'fuck BREAKING MUSIC @apple',
#  '@Apple TV fade away #streaming video player market',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '#mkt Final #AAPL #PutCallRatios Tuesday, December 2, 2014:',
#  'APPLE - Fibonacci Technicals Levels - Intraday Update - $AAPL #aapl',
#  "Congrats @apple making iPhone recording DRM protected can't play anywhere want #fail",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  "CAN'T DATE CAN'T CLONE ME? come thru @apple",
#  "@thehill @Apple @tim_cook @WhiteHouse @jmhattem Obviously part left's multi-talented, super-successful gay business agenda.",
#  '@Apple need sort phone out.',
#  'We love cocktail @Apple Jacks want share favourite cocktail you! Pop in...',
#  'Trade $AAPL #FREE Nightly Updates #posted #Twitter, visit #Trade #AAPL FREE #website',
#  'The Amazon Enigma #AAPL #AMZN #BABA #ecommerce #econsumerism #Financial #News',
#  'FUCK FUCK IM SOOOOO SLEEP FIX SHIT @APPLE',
#  'OK, @apple - guess app developer takethis weeek off, huh?',
#  '#AAPL:Avago Technologies (AVGO) Stock Skyrocketed Close Higher Today P...',
#  '@nheagy @apple need stop auto arranging home screen, allow user position apps wherever want.',
#  '#AAPL:The Tell: Apple patent way save iPhone dropping breaking...',
#  "RT @hoetbh: CAN'T DATE CAN'T CLONE ME? come thru @apple",
#  '6 Reasons Apple Could Have Fallen 6% Yesterday $AAPL #aapl',
#  "'@GMONEYizME: I've probably spent replacing non functioning Iphone cable I've spent iPhones @apple' - #SwitchToLumia",
#  'Poor dude gettin slandered want argue @apple',
#  'Another @nike #mustbuy #outfit @apple #ipodnano',
#  'Those** PICK SLACK FUCK BOYS @Apple',
#  'RT @aaaron: Insanely great news. @adroll team @apple iAds programmatic launch',
#  '@Apple #ipad #innovation let u maintain enjoyed young via @HuffPostTech',
#  '#AAPL:John Sculley Pans Apple Watch, Loves Apple Pay...',
#  'RT @thehill: Justice Department cite 18th century federal law get @Apple unlock iPhones:',
#  'MacBook Pro 13in Unboxing: via @youtube @apple #macbook #macbookpro #startup #hipster #unboxing',
#  'Top 3 @Apple #tablets. Damn right!',
#  '@SonyUK see even courtesy reply said stayed @apple much better customer service',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  '12 Gift Ideas For The Apple Lover Who Has Everything @apple #technology',
#  '@OneRepublic @Apple Pleaseeeeeeeeee',
#  'CALLER ID must able BLOCKED @AppIeOfflciaI products. @applenws @apple #Apple #iPhone6 #iPhone6Plus',
#  "Why fuck 'recently deleted' photo album? @Apple",
#  '@Apple store #nyc honored here. #travel',
#  '@Apple made clear today customer worth measly $79!! An employee gave mi info stand behind',
#  'Have cashed #AAPL #CFD - $110 $113 inside 4 hour - brave sometimes!',
#  "@Apple retail location offer free coding workshop Dec 11th part 'The Hour Code'",
#  'Not sure want 6 6 plus @apple #iphone6 #iphone6plus #iphone',
#  'Elgato Launches Thunderbolt 2 Dock 4K Resolution Support [Mac Blog] #AAPL',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'Apple Bears Get Fat Payout From Stock Swoon; 60-Second Plunge $AAPL #aapl',
#  'Perceiving Misalignment: Facebook Vs Apple, Ello #AAPL #Ello',
#  'Apple Is Warming Up To Social Media: Apple hiring social medium guru L.A. Will @Apple finally tweet?Her...',
#  "LUV @apple #iphone I've pretty much iPhones. #3GS, #4 , #4s , #5c &amp; #MobilePhone",
#  'HATE @APPLE MUCH. RUIN LIFE',
#  '@apple #macos #yosemite buggy piece shit. It make miss #windows8.',
#  '@Apple EVEN REAL FUCKING APPLE COMPANY FUCK SUPPOSED',
#  "'#Trademark Confusion: While @Apple App Store #Trademark rejected Australia, approved Europe &amp;...",
#  'RT @pyalot: @Apple @appleios rolled #WebGL #iOS8 3 month ago overtook @google @Android WebGL support levels.',
#  "MFN international trade. It's key issue @apple's #ebook appellate case say @rparloff.",
#  'RT @HorseshoeBmore #Holiday #Giveaway! To ensure stay touch go ck brand like @Apple @amazon',
#  'We need product like .@Aviate Companies like .@BlackBerry &amp; .@Apple need embrace customization quality themes.',
#  'Thank u @apple compile pic communicate one place',
#  "RT @_JuGatti: Wouldn't bad idea bring back tap tweet function guy @apple @twitter",
#  '@SimplyYours_Joh @Tyniaaaa_ @JColeNC @Apple yeah',
#  'Final #AAPL #PutCallRatios Thursday, December 4, 2014',
#  'RT Chayton Falke ChaytonFalke :#Nasdaq100 #recent #market #exit #4: Sold $AAPL long 10.49% #gain 20 days. #AAPL #forex #trading...',
#  '#YotaPhone2 future cell phones. @apple @samsung scared.',
#  'Apple Is Warming Up To Social Media: Apple hiring social medium guru L.A. Will @Apple finally tweet?Her...',
#  'Way go @apple',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'New @Apple Patent From PrimeSense Covers Kinect-Style 3D SpaceåÊMapping via @techcrunch #cooltech',
#  '@daulfn @AppleUK_ @Apple Windows lappy work well half price alternative',
#  '@swerviinnn @Apple hostile tn',
#  '#apple earns #profit quarter #amazon earned lifetime. Amazon @apple WoW Facts...',
#  '@apple fuck',
#  'Happily, @apple restored faith today Arndale Store following earlier complaint.',
#  "#AAPL:One Of Apple's Earliest Employees Describes The First Time Steve Jobs ...",
#  'CNBCTV: #Apple fighting monopoly allegation #aapl',
#  '@Apple You old product available people economic standing current market sec. @AppStore',
#  '@JustinPulitzer Any comment #aapl today?',
#  'iPhones mad sensitive bro, cold, dy even lot battery left. If hot, shuts well SMFH @Apple',
#  '@whereiscooldude @Apple kind thought hand',
#  'Get three way FaceTimeing. Im sick google hangouts. @Apple',
#  '@apple #apple corporate raider selling weak product stop working within weeks&amp;apple get warranty claiming dampness',
#  'proof @apple use products. freaking MAIL show SEARCH FILE FINDER! nut kicks.',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'Is @apple searched company @google searched platform?',
#  'See Which 11 Guru Fund Managers Hold #Apple #aapl',
#  'Why hate business much @Apple?',
#  'RT @thehill: Justice Department cite 18th century federal law get @Apple unlock iPhones:',
#  "RT @SwiftKey: We're excited named @Apple's 'App Store Best 2014' list year! #Apple",
#  "@Apple [#Apple]'s #IPhone6Plus capture Christmas #White House. (#Friday, 5 #December)",
#  'Apple Is Warming Up To Social Media: Apple hiring social medium guru L.A. Will @Apple finally tweet?Her...',
#  '@apple despite fact mpeg 2 component CAME PURCHASE FINAL CUT PRO.',
#  '#IPhone6 #Plus Captures 41% US #phablet Sales #aapl',
#  "Apple's iPhone 6 Plus Amazingly Captures 41% Phablet Market Right Gate $AAPL #aapl",
#  'GVA lounge: sight 6 Macs 3 PCs + undetermined number iPxs! #AAPL',
#  'hate @iTunesMusic @apple',
#  '#WIN #DIGITAL MAKEOVER #GIVEAWAY ! $1000 @APPLE GC,#IPAD #MACBOOK ! #PIN',
#  "Pegraton may Gain Orders 50% 2015 4.7' iPhone 6S $AAPL #aapl",
#  '#brooklyn changing! @apple store heading BK!',
#  'How Apple Will Boost Profits During Holiday Quarter Beyond $AAPL #aapl',
#  '@OneRepublic @Apple Follow meeee',
#  '@jimmymujaj @Apple work fucker, hoe one person SMD',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '@baseballbridget @apple even get turkey TDay care... #appleemojissuck',
#  'Can @Apple survive 2014 Holiday? Investors Say Yes.',
#  'Your stupid shit upgrade ruined god damned IDE @apple',
#  '#AAPL:Steve Jobs Defends Apple Taped Deposition...',
#  '@carlquintanilla @CNBC Where would be..if #AAPL Dow. sarc..',
#  '@afrobugeisha @Apple lol',
#  'Brilliant Tech! No broken screen #festivals, @Apple via @techcrunch',
#  '#Apple: Market Maker Price Range Forecast Update #AAPL',
#  '@TeamCavuto @JustinRaimondo @Apple',
#  '. @Apple patent drop-proof mechanism. Breaks law physic anti-gravity. via @tomshardware #getagoodcase',
#  'From afternoon tea @Apple #iPadAir2, something everyone #touchpoint rewards. - Visit info',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  '@viticci @panic @Apple Jesus, create extension all? Lighten Apple.',
#  "Will Apple Inc.'s Profit Margin Continue Upward? #AAPL",
#  '@Apple fix devices!!! Some album available iTunes download illegal happens.',
#  "RT @baImains: um where's mango emoji @apple",
#  "Apple Transitions 'Find My iPhone' Web Maps From Google Apple [iOS Blog] #AAPL",
#  'Apple iPhone 6, 6 Plus Retina iMac ship time improve time holiday $AAPL #aapl',
#  'swear fuck would rather cut splice physical fucking tape dick around one @Apple product shit design.',
#  '@YouKantFindMe @Apple kashka clave mind',
#  '#iPhone6 sale success give @Apple [#Apple] best ever UK market position. (#Thursday, 4 #December)',
#  "@Apple power cord problem- warranty. You said would fine. It isn't. And replace it?",
#  "I'm happy now, thnx fags. @apple",
#  "Help? 4 sync (doesn't even give option) w/ latest @itunes. Tried fix found... bueno. Thoughts? @apple #techsupport",
#  '@Sony @Apple @iTunesMusic @AppStore @tim_cook need combine effort make one solid system accessible device...',
#  'really @apple? search tool USELESS. nut kick',
#  'APPLE Intraday Comments - Updated RANGE - PREMIUM USERS #aapl #Stockaction #trading #Stocks #MKt',
#  'Apple Inc. v Google Inc: The Battle Of The Tech Giants $AAPL #aapl',
#  'Ha, poor @apple trying make iPad MacBook look useful commercials. Not even close power @surface Pro 3',
#  'Myths vs. Reality Full-Time #Trading #stocks #futures #forex #trader #es #nq #cl #aapl #gpro #finance #eSignal',
#  "RT @SwiftKey: We're excited named @Apple's 'App Store Best 2014' list year! #Apple",
#  '@SealsKevin @TeamCavuto @Apple Hopefully endangering lives!',
#  'Citi, BMO boost Apple price target #News #AAPL #Applepricetargets #Applestock #Apple #iPhone #News',
#  "iPhone 6 Plus Captures 41% 'Phablet' Sales U.S. $AAPL #aapl",
#  'Apple: Canaccord, Merrill Up Targets iPhone Cycle; Mostly Priced Stock, Says Pac Crest $AAPL #aapl',
#  'Next year goal #Apple free. Tired BS. @Apple @iTunesSupport',
#  '#AAPL:iPad Mini 3 v Sony Xperia Z3 Tablet Compact: Step Aside Sony, Apple S...',
#  "#SteveJobs' Emails Show How He Wanted To Smear Competitors As ' #Hackers' #aapl",
#  '@apple get shit together group chat ios8',
#  'Amazon (AMZN) Ecosystem: The Biggest Threat #AAPL Stock: amzn Amazon (AMZN) Ecosystem: The Biggest Threat t...',
#  'RT @JPDesloges: Plaintiff withdrawn iPod antitrust lawsuit $AAPL #aapl',
#  'Got new cases. :) @apple @applestore @citycreek #slc #citycreek #apple #applestore #red ...',
#  '@Apple lol. Yea bro.',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '@apple #ios8 The lack true keyboard integration KILLING me! Half-assed implementation solutions!',
#  '#iPhone6c release date, #rumours #leaked images: @Apple [#Apple] said #be working .... (#Friday, 5 #Decem...',
#  'CNBCTV: #iPhone growth peaked? #aapl',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '@apple Contact sync Yosemite iOS8 seriously screwed up. It used much stable past. #icloud #isync',
#  "This new phone suck can't make stand side can't wait iPhone 7 @apple fix dingle",
#  'Is Apple (AAPL) Stock All It Is Hyped To Be Or Just Another Dot Com Disaster ... #AAPL',
#  'MacBook Pro 13 Non-retina First Startup: via @youtube @apple #macbook #macbookpro #startup #hipster',
#  "@googlenexus Support said can't test NFC can't assume phone working. Keep saying can't HELP. I'll go back @Apple.",
#  '@apple @iphone @emoji 2014 canadian flag emoji keyboard?',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  '@Apple seems nailing @applepay, building success &amp; brand #AppleID #NoMorePaywords',
#  "Taking Apple's Lead, Amazon Gets Physical - News - Harvard Business School @HBS @Apple",
#  'RT @OvelhaNegraTV: Apple TV fade away streaming video player market - @Apple #vod #streaming',
#  '@MhDaDon @Apple def gotta it, even like watch',
#  'tell ur update stop capitalizing everything @apple',
#  '@Google Chrome Books OVERTAKE @Apple device Education market! via @CNET',
#  'TheStreet: Why Even #Apple Is Surprised Enormous Demand #iPhone6. #aapl',
#  '@apple fuck yo shit',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '#AAPL:6 Reasons Apple Could Have Fallen 6% Yesterday...',
#  'Final #AAPL #PutCallRatios Friday, December 5, 2014 via Hamzei $$',
#  '@weightsmate @Apple total nightmare!!!! take big slice cake !',
#  'We need eye rolling emoji pronto @apple',
#  'need new emojis , preferably brown people shxt like @apple',
#  '#chrome need fucking update ASAP. Why @apple @google play stupid back n forth shit software. #letmecreate',
#  'Cyndi Lauper Cinna- big ask* phone TV @apple #iphone6plus @ Rockefeller Center',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'RT @Amdocs: Top #iOS apps 2014. @Apple name Elevate Brain Training #1 iPhone app.',
#  'Hey @apple reading list safari across device rocks, please let list item deleted (x) iPhone',
#  "My daughter's @Apple #iPod stolen. To thief: try working hard earn one - like daughter buy hers. #LosingFaithInPeople",
#  '#AAPL:Canaccord ups Apple price target $135 share...',
#  "I'm playing game @JColeNC @Apple",
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'Apple Inc. Patent To Protect Falling iPhones Is Approved #AAPL',
#  'RT @HamzeiAnalytics: BLOCK TRADE detected #AAPL',
#  "It'd real cute could sync music phone @apple @god :-)",
#  'An OSX update bricked MacBook Pro!. @apple fuck..',
#  'Feed My Ego (Futter Mein Ego) iPhone 4/4S Tough Ca COMPUTING &amp; COMMUNICATION Melasdesign @cafepress @iphone @apple',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'Hey @artsboston #UrbanNutcracker Russell Ferguson @RussellFerg &amp; #krumpers @Apple Store Boylston St. @5.30pm today. Dancing &amp; chat',
#  "Apple's PT raised Citigroup Inc. $135.00. $AAPL #AAPL",
#  'RT @DecodedFashion: .@Apple reportedly hiring fashion-focused staff physical store #FTDaily #FashionTech',
#  "Pacific Crest's Apple Analyst Reiterates Selling Some Shares $AAPL #aapl",
#  "4-inch #iPhone6: Five Reasons #Apple Won't Make It - Forbes #aapl",
#  "Loving Samsung one Kristen Bell. RT @adage: Watch weekend's new TV ad @RadioShack, @Apple",
#  'RT @Cyrus_T_Virus: Why vomiting emoji yet, @apple',
#  'Final #AAPL #PutCallRatios Monday, December 8, 2014 via Hamzei $$',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  '@apple laughing pant school program Australia. They even manage wringe money poorest people',
#  "Here's @Apple's next great #business! What Apple's primary source revenue 2015? #service #company",
#  '@apple award @RegisCollege_MA Distinguished School honor. #iPads',
#  '#AAPL:31 Traits All Great Leaders Share...',
#  'APPLE - Fibonacci Technicals Levels - Intraday Update - $AAPL #aapl',
#  '@phone @apple FUCKING HATE YHIS OHONE OMG IM EMBARRASSED',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'RT @T21Century: Translate Your App! Success story TAUS member @smartling - go global @Apple, @Tesla, @GoPro',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @thehill: Justice Department cite 18th century federal law get @Apple unlock iPhones:',
#  'RT @JPDesloges: APPLE - Fibonacci Technicals Levels - Intraday Update - $AAPL #aapl',
#  "@applenws @Apple @AppleProducts Ok yall need reverse phone back iOS 7 bc can't anymore",
#  'RT @thehill: .@Apple CEO @tim_cook visit @WhiteHouse @JMHattem',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'Steve Wozniak Says @Apple Starting In Garage Is Complete Myth @stevewoz-',
#  "RT @ConsumerFeed: Apple's PT raised JMP Securities $150.00. outperform rating. $AAPL #AAPL",
#  '#BlackBerry: Analyzing The Secusmart Purchase #BBRY #AAPL',
#  '@NevBackwoods exactly. Come @apple / phone companies, get yo shit together',
#  "RT @dmcgroarty: RT @MetalBanker - Where #iPhones come from? What's @Apple #RareEarths",
#  'RT @HorseshoeBmore #Holiday #Giveaway! To ensure stay touch go ck brand like @Apple @amazon',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '#aapl @applenws Thanks non factual dumb Twitter follower stock drop 3 point one minute. Thanks dummies. #rumors',
#  "Watch weekend's new TV ad @RadioShack, @Apple",
#  'Technology Sector Update 12/02/2014: NTLS, #AAPL, TMUS, S: #Nasdaq: set go trial Tuesday regardin...',
#  'New @apple problem. At airport. Boarding pas phone. Held scanner security, #ApplePay credit card take screen.',
#  'Facebook CEO Mark Zuckerberg criticizes Apple $AAPL #aapl',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  '#Apple, #PayPal, And #MobilePayments Worldwide #AAPL',
#  "#AAPL RT @AboveAvalon Apple's Share Repurchases Have Benefited Shareholders $80 Billion",
#  "#Apple: Facing Challenge From #Google's #Android #AAPL",
#  '#AAPL:My Three Horsemen Of The NASDAQ 100: Apple, Microsoft And Gilead Scie...',
#  'The company crushing @Apple Samsung China making amazing super-cheap phone',
#  '@CHAYILTrading #ChartOfTheDay Apple #AAPL',
#  '@Apple set timetable (rather chasing #competition) focusing #customerexperience #cx #cem',
#  '#AAPL:Accel Partners Leads $50M Series C Funding DataGravity...',
#  '#Apple Wants To Make Your Commute Much Easier, According To This New Patent #aapl',
#  '@apple want picture back',
#  'Apple CEO Tim Cook come gay @Apple Via @posh360_Net',
#  'The rumoured @oppo R8207 look similar certain @Apple #iPhone6',
#  'Apple Inc. (AAPL) iPhone 6 Sales Dent Android Market Share #AAPL',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  "@apple one iPhone 5 speaker stopped working, that's cool..send iPhone 6 forgive",
#  "hell lucy's song delete phone HATW @iTunesMusic @apple",
#  'Great piece @howardlake @apple &amp; new #RED #app store - profit exclusive content go @GlobalFund:',
#  '.@Apple rules, .@Windows &amp; .@BillGates blow!',
#  'Love @apple #iphone5 need upgrade soon',
#  'Washed earphone accident, still works. Thank @apple , actually something good',
#  '@CadeRageous Thx RT .@Apple Own 2600 digital language (IP) = NEW #internet Leader,10% cost #DIY .@googlenexus',
#  '$118+ tomorrow #AAPL',
#  "@TeamCavuto @SharNeal @Apple 'Hey Bro, check ipod I'm here?'",
#  'love @AIRMILES! Between @chaptersindigo &amp; @apple earned ~200 mile #BlackFriday sale! #freemoney #centsability #cybermonday',
#  "@carlquintanilla Thanks #AAPL coverage, we're deeply invested one stock; biz can't ignore it....",
#  'second phone charger broke two week @apple hate',
#  'RT @FullCircleOne: @Cleosbaby64 @Apple @stackizshort Thank You Good Coverage W/ NoFear',
#  '@Apple Pay = Compuserve | BTC = internet',
#  "@OneRepublic @Apple wow that's amazing",
#  '@OneRepublic @Apple heck playing computer across brent',
#  'RT @JPDesloges: Apple Watch Track February 2015 Release, Testing Underway [Rumour] $AAPL #aapl',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  '@apple fucking let everyone name group chat thing please thanks',
#  'Is Apple The Most Important Stock On Earth? #aapl',
#  'Apple Inc. Flash Crash: What You Need Know #AAPL',
#  'Great piece @howardlake @apple &amp; new #RED #app store - profit exclusive content go @GlobalFund:',
#  'RT @FaZeNikan: yea let pay 600 dollar phone dy 30% fix shit @apple',
#  'RT @thehill: Justice Department cite 18th century federal law get @Apple unlock iPhones:',
#  "@SuzanneBoyd @Apple Is chic-filet mug he's holding? My daughter brought character home talks...absolutely hilarious.",
#  'Apple go trial $1 billion digital music lawsuit California $AAPL #aapl',
#  "Eddy Cue Speaks Apple's DRM Policies iPod Antitrust Lawsuit #AAPL",
#  'You able leave FaceTime video message @apple',
#  "@TeamCavuto @CaliCard1 @Apple It's handled well folk like think Eric Garner's death simply go away.",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'T-MOBILE/APPLE CELLULAR HELL! @apple @TMobile #iPhone6 #iPhone6Plus #Apple #TMobile #tech',
#  "#AAPL:Here's Why Apple Won't Be Trillion Dollar Company According To Billi...",
#  "You'll back life soon @apple",
#  'It look like software update saved storage IPhone. Can delete need it? @Apple #Applesupport',
#  'UK: Where buy #iPhone6, iPhone 6 #Plus, iPhone 5S, iPhone 5C, iPhone 5, iPhone 4S #aapl',
#  '#AAPL:After Decades Of Consolidation, Wall Street Is Fragmenting...',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  "Had job interview?No idea @apple specialist #students need teachers! It's #humanrights issue @DrArik",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  '@apple train employee deal issues?? To hang customer? After 15 fucking minute waiting hold',
#  '.@Google Trumps @Apple In Streaming Media Sales @mp_gavin',
#  'RT @Anna_Cochrane: Looking crazy George Street, #Sydney rain @Apple Genius Bar...',
#  "I'm going check got it. @Apple TV get four new channel @YouTube redesign via @cultofmac",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Is #Apple Inc. Losing $5 Billion Ed-Tech Market? | The Motley Fool #aapl',
#  '@google @facebook @intel @apple Pay tax country!!!',
#  'Apple CEO Tim Cook come gay @Apple Via @posh360_Net',
#  'Seems like @apple #customerservice going downhill say need new battery due 600 charge 14 months. å£50 change.',
#  'evolution Apple products! @Apple',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
# ...
#  'Is #Apple Hedging Bets Another Small #iPhone? #aapl',
#  '@remuuusss @apple fix',
#  '#AAPL:Did Carl Icahn cause new private equity bubble?...',
#  "Is Apple symptom tech bubble? Could Apple overvalued? 700B Reasons Apple's Valuation: #Apple #AAPL",
#  '@Mzhoov @BionicBombshell They got nigga turban. Why cant sista headscarf @Apple?!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Almost want back android Apple torrent?@apple',
#  'Details #Apple Inc. #iPadMini4 Revealed | The Motley Fool #aapl',
#  '@apple iBooks pick OPERATION PAPERCLIP one Top Ten NonFiction Books Year. #BestBook2014 #iBooks2014',
#  'ACTUAL FUCK @apple',
#  '@EE Did yesterday... again! Told issue @Apple @EE .This added worst 3 month customer service ever!',
#  '@zoebread dp developments; welove #AAPL-E new #retina screen ohai',
#  'iPad Mini First Time Startup!: via @youtube @apple #ipadmini #ipad #macbook #macbookpro #startup #hipster #unbox',
#  '@OneRepublic @Apple look amazing, think anyone say recorded music plane haha',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @TheywantVonnie: Dear @Apple Can please create middle finger emoji ASAP Sincerely, All IPhone user',
#  "RT @hsmoghul: My @apple autocorrect change Muslim awesome I'm okay",
#  'Congratulations @Apple firmly reasserting top most-hated corporation list today. #justnotabumfluffbohemian',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Here @SFBJEditor 5 thing know today, including hoarding @Apple #iPhone6',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '@Apple co-founder Steve Wozniak talk Steve Jobs &amp; Apples early days. via @DesignTaxi',
#  'Is happening #iTunes account? @Apple secretly deleting non-iTunes music.',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '#AAPL:Apple trial continues, without plaintiff now...',
#  'CNBCTV: #Apple arguably innovative company world: Pro #aapl',
#  ".@Sony named 'most-desired brand' #BlackFriday &amp; #CyberMonday, beating #tech rival @Apple: via @TheDrum",
#  "RT @chemixcalbieber: '@WhoaBiebz: GET SHIT TOGETHER I'LL GUY SAMSUNG GALAXY S5 @APPLE'",
#  "I'm learning Apple iPad mini Smart Cover - Pink (MD968LL/A) @Influenster! @Apple",
#  'RT @SanfordDiday: New @Apple Patent From PrimeSense Covers Kinect-Style 3D SpaceåÊMapping via @techcrunch #cooltech',
#  'Gotta love Genius Bar @ @apple!! Thanks help Alex!! @ Apple Store, Suburban Square',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Apple Seeds Second OS X 10.10.2 Yosemite Beta Developers [Mac Blog] #AAPL',
#  'APPLE - Fibonacci Technicals Levels - Intraday Update - $AAPL #aapl',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '@ace_kit_uk @office_nerd @Apple Is deal still available?',
#  'YES LOVE NONE STUFF WORKS THANK @APPLE',
#  'RT @FaZeNikan: yea let pay 600 dollar phone dy 30% fix shit @apple',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'So, Which #PromoProduct supplier carry brandable @Apple compliant adapters? #HeadsAreGoingToRoll #MFi',
#  'MacBook Pro 13in Unboxing: via @youtube @apple #macbook #macbookpro #startup #hipster #unboxing',
#  'Come #aapl, get shit together!',
#  'No @macbook today,charger broken .help please @apple do...',
#  'RT @elnuevoherald: Steve Jobs, clave en juicio contra @Apple',
#  'Great! @Apple board #Alabama #LGBT bill named CEO #equality #Tim #Cook @equalityalabama',
#  'As die hard @Apple customer, must say truly displeased customer service given today. #badservice #Apple',
#  'need @apple come charger cord keep charge &amp; fall apart',
#  'Day 338: 1st iPod 2005. Had stopped workin year ago!!! Just Came back life!! Wtf @Apple',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Go Apple! Looks like little squeeze :) #aapl $stocks',
#  "Dear @Apple yall please stop making yall charger cheap piece shit I'm tired replace every 3 monthd",
#  "Now nice 'Cup Handle' #stockcharts #FB #TWTR #AAPL",
#  "Who hell @apple thought, let's put volume display front video. Absolutely dumb. Miss video every time adjust volume.",
#  'We know Raul going LOVE brand new art supplies! Thank @SarahInThisCity @Apple!',
#  'This would never want @apple device. But sadly people seem okay that.',
#  '#Apple Inc. Catching #iPhone6 Supply, But Still Lagging Demand | The Motley Fool #aapl',
#  'Is me, feel #Yosemite eats battery &amp; Resource #Mavericks? @Apple reading this?',
#  'RT @shannonmmiller: Love @Apple supporting #HourOfCode workshops! :)',
#  '@angusdick yes, exact issue. Took @apple free battery replacement. Trackpad ended fine.',
#  "It's important Apple become developer world. We need people invent stuff.' - Tim Cook CEO @Apple",
#  "'@apple: MacBook @ray_alexander_: Apple. need MacBook byke.'",
#  '#apple expand #retail #India opening 500 new stores. @Apple',
#  "Why can't FaceTime one person time @apple ? need answer dammit oovoo winning.",
#  'RT @JPDesloges: Apple Support New Franchise 500 iOS Stores India $AAPL #aapl',
#  '@apple FUCKING HATE',
#  '@_emilymahon @nosheenh2oo9 @Apple shut hell',
#  '@GriffinNW @Apple @tacobell love @tacobell!',
#  "@HRHound @MandoGallegos Nice! If actor iWatch he'd entire suite @Apple products. #sponsorDeal",
#  "Eddy Cue Speaks About iBooks Price-Fixing Case: 'We Feel We Have Fight Truth' #AAPL",
#  '@nialIhburn @Apple TRES',
#  'Our new @Technogym treadmill getting assembled. Could better @Apple #CarPlay compatible...',
#  '@apple Excellent customer service thanks Ian #applestorecoventgarden',
#  'black jawn getting scooped like ice cream RT @Ms_BiAnCa_BiSa: @MhDaDon @Apple def gotta it, even like watch',
#  'call wit amanda keep ending @apple fix urself',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  '@apple - bring back #classiciPod #cantbelieveitsgone',
#  '@Apple charger SUCK',
#  'Hey @apple, iPhone 6 fully charged 7:30 am. Now 20%. Is common battery life?',
#  'How many iphone charger need go through? @Apple make charger durability point new iPhone',
#  'RT @saxonidubom: @rwang0 @Apple Thanks...thinking upgrading.',
#  "applied @apple's 'head social media' opening. leg twitter skillz. like mark twain twitter.",
#  ".@Apple CEO's name grace Alabama antidiscrimination bill |@SDGLN @KenSanDiego @Benny_C @jimwinsor @mistercervantes",
#  'L.A. school district halt iPad contract FBI seizes document $AAPL #aapl',
#  '@jengolbeck @Apple agreed',
#  'My phone died 8%, would let happen @apple?',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  '@apple fix o x please.',
#  '@Apple please make charger actually last',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Apple Pay add issuer L&amp;N Federal Credit Union, UW Credit Union M&amp;T Bank $AAPL #aapl',
#  'Tryng get back snapchat App Store cooperating @apple',
#  'transpartent resin infused #composite structure @apple',
#  'Help @Apple. Store rep told iTunes backup save multiple backups. But backed phone old backup gone. What do?',
#  '@apple @iBooks awesome. Thank You!',
#  'What Happened To Apple Inc? #aapl #apple @MoneyPress',
#  'Apple Inc. Campus 2 Has $161M Auditorium, $74M Fitness Center #AAPL',
#  '@ATTCares @senisbs Wireless Family Share plan, one line upgrade killed discount. Not sure mentioned @Apple pre-order page.',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'Apple Planning New Retail Store Williamsburg, Brooklyn [Mac Blog] #AAPL',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  '@Apple otter emoji',
#  '.@panic The inconsistency overall weirdness control @apple #appstore archive previous versions.. easy downgrade.',
#  '@FaZeNikan @Apple lol iPhone,weak. Get Lumia level bruh',
#  'RT @BGPublic: Even reason @Apple stop using benzene manufacturing.',
#  'Updated Yosemite two machines. Both painfully slow. Thanks, @Apple.',
#  'Will Apple Pay Consumers $1 Billion For Deleting Their Music? #AAPL',
#  '@apple What need mac really slow lately ?',
#  '@apple fuck bitch phone abrick stuck apple logo',
#  "Don't worry @bentkraus. crash anything. Not even @Apple stop",
#  '@apple, really know mouse battery inceased charge since last time mac told low',
#  '#AAPL:Did Carl Icahn cause private equity bubble?...',
#  'Paid $20 new 5 charger b pissed it... rape @apple',
#  '@stevewoz @harveystahoe @apple Patent Number patent 8,903,519',
#  'Sketchy Rumor Claims Apple Planning New 4-Inch iPhone 2015 #AAPL',
#  '@hoos @apple navigate way',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Congrats @Apple mean using @googlehangouts_, right? #Apple #Google',
#  "Yeah, I'll definitely going @apple store finals. Damn MBP Graphics card failing again, bullshit $2500 computer",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  "@apple official 2 appletv's constantly loosing network co, Watching tv medium impossible, Can",
#  '@BlackBerry kinda feel sorry @Apple tho. #GoodJob last product guys!',
#  '1% plug phone jump 4% @apple stop playing game',
#  'Terrible service @Apple store Bethesda, MD. Second time. Will buy new iPad &amp; cover ($950+) @BHPhotoVideo. @tim_cook @h_posner',
#  '@Noctylux @finalcutproes @macnificos @Apple refurWHAT??',
#  'How Apple Is Crushing Google On Mobile Shopping $AAPL #aapl',
#  '#Apple Inc. #Facebook Clash; Neither Is Wrong | The Motley Fool #fb #aapl',
#  "Can't get new iPhone 6? How free Apple shares.... #investing #stocks #aapl",
#  '#ApplePay Partner #Stripe Valued $3.5 Billion Funding #aapl',
#  'The 19-Year-Old #WizKid Who Turned Down @Apple Has Nabbed Backing From #Hollywood Star',
#  'RT @shannonmmiller: Love @Apple supporting #HourOfCode workshops! :)',
#  'Suit Against Apple Over iPods May Lack One Thing: Plaintiff $AAPL #aapl',
#  'My iPod touch case 5 @apple #ipodtouch5thgen',
#  '@jaureganoo @Apple say start riot. something. supply pitchfork',
#  "iPhon6 rival Samsung, LG,HTC suffering delay Qualcomm's 64-bit Snapdragon answer Apple's A8 $AAPL #aapl",
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  "Pop #BostonHoliday - #UrbanNutcracker's @RussellFerg &amp; #krumpers @Apple Store Boylston St. @5:30pm today. Dancing &amp; chat'",
#  '@agiletortoise Once @apple inconsistent app rule maintain Plausible Deniability. Sorry hear Greg @draftsapp',
#  "@Google, @Apple @Unilever world's in-demand employer @LinkedIn",
#  "Apple's PT raised Bank America $130.00. $AAPL #AAPL via @RatingsNetwork",
#  ". @apple think '59' close '00' setting alarm iPhone. Many time fallen victim this.",
#  "If can't make receive call iPhone: You might able make receive call yo... @apple",
#  "@wastwater1 l agree you, they're robust chocolate fire guard @Apple @traffordcentre",
#  '@thehill @Apple cite 4th amendment retort',
#  "Major crisis avoided @apple. You guy able restore daughter's #iPhone. Great service, thanks. #5starservice",
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  'Basketball Game Day: V Boys vs. Silver Valley 4:00 PM (@Apple Valley) V JV/ V Girls vs. Noli 6:00 PM (Mac)',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  "CNBCTV: Buy #Apple's pullback? #aapl",
#  '.@google Trumps @Apple In Streaming Media Sales',
#  "AFP request Apple reveal 'get warrant' pushback @zdnetaustralia @Apple #tax #evaders ripping Aussies",
#  '#VerrÌ_cktes #GerÌ_cht: #iPhone6s zum @Apple [#Apple] Watch. (#Thursday, 4 #December)',
#  'alarm set ringer refused work fuck u @apple',
#  'hate much @apple @macs',
#  'iPhone charger suck as @apple #disappointed',
#  'The Best #iPhone Apps Of The Year, According To @Apple',
#  '#iPhone6 #Plus Grabs 41% U.S. #Phablet Sales #aapl',
#  '#Apple begin hiring retail position Brussels ahead first #Belgium ... - #AAPL',
#  'RT @TypicaIStoner: RT think @Apple approve Emoji',
#  '#AAPL:Steve Jobs Gives Posthumous Testimony In Apple Trial...',
#  '@Apple @iCloud Family in-app purchase approval broken since Friday? You might unhappy, money-losing developer come Monday.',
#  'dear @Apple get shit together',
#  'BREAKING: #NYC #EricGarnet protestors occupy @Apple story #NY #ICantBreath 11x LIVE @Rebelutionary_Z',
#  'As die hard @Apple customer, must say truly displeased customer service given yesterday. #badservice #Apple',
#  "split The Valley user data? @Apple says, 'totally.' @facebook &amp; @google say,'like, whatever!' #titianfight",
#  'Shockingly, iMessage desktop fucked again. Great work, @apple. Seriously, point network service do.',
#  '@apple @jetbrains It happened - perhaps network? This setting :',
#  "Excellent news #HouseOfCards S3 @netflix 27/2! wonder Yosemite &amp; wifi talking @apple @tim_cook ? It's wks!!",
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  "JMP raise #Apple price target Street-high $150 'exceptionally strong: Apple Insider: #AAPL: 115.49 (-0....",
#  '#Nasdaq100 #recent #market #exit #4: Sold $AAPL long 10.49% #gain 20 days. #AAPL #forex #trading #stocks',
#  'Apple CEO Tim Cook come gay @Apple Via @posh360_Net',
#  "@brettgilmour @Apple You're one apparently, based last interview @carmilevy",
#  'fuck apple allowing ppl access camera phone locked fuck fuck @apple',
#  "@allandthompson @Apple Let go ahead get one way: 'U gonna get VIRUS &amp; ur whole house explode!'",
#  'TheStreet: #Apple Gets Price Target Boost Back Strong #iPhone Demand #aapl',
#  'dear @apple, oh baby sit copying file POS Finder? like copying file hard. oh wait, you.',
#  "Steve Jobs' Snarky Testimony Takes Center Stage iPod Class-Action Lawsuit Opening #AAPL",
#  "#Apple's Recent Pullback Buy Opportunity #AAPL",
#  'RT @smartoutsource1: @Apple #iPod lawsuit reveal unseen Steve Jobs video',
#  'BLOCK TRADE detected #AAPL',
#  'Apple Is Warming Up To Social Media: Apple hiring social medium guru L.A. Will @Apple finally tweet?Her...',
#  '@FaZeNikan @Apple restart wait till next Apple update happens',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'Apple Plans Launch iPhone 6 Mini Version 2015 $AAPL #aapl',
#  "@Apple loses appeal trademark 'app store' #Australia",
#  '@Apple Is Already Building Its Next Massive Business And No One Seems To Have Noticed',
#  "Intel &amp; Jesse Jackson's RainbowPUSH host tech employee diversity event Silicon Valley #intc #goog #aapl #fb",
#  "dang phone fuckin sucks. fuck @apple!!! piece shit iPhone man. y'all disappoint me.",
#  '@apple loosing thing used make much better live window',
#  "2/ At announcement @samsung supporter criticized #AAPL 'following' Samsung large screen game.",
#  'How #profit #Apple (#AAPL) #options #trade #trading #finance #short #bet #hedge',
#  'RT @TeamCavuto: Protesters stage #DieIn protest @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#  '#AAPL think valued 140-145s next year.Death Steve Jobs damaged #Samsung Apple +',
#  "Refusal @Apple's #TM application APP STORE upheld Australian federal court. Apple appeal. @IPAustralia",
#  'Need lock #Sponsorship deal @Swatch , @Nike &amp; @Apple Thank cooperation. Regards, Uncle Mike',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need battery future NoW!!!!',
#  ...]

# %%
def clean_tokens(text):
    return text.split()

# %% [markdown]
# ## Análisis de la Representación Vectorial

# %%
from sklearn.model_selection import cross_val_score

from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier

# %%
def run_model(clf, X, y):
    scores = cross_val_score(clf, X, y, cv=5)
    print("%s accuracy: %0.2f (+/- %0.2f)" % \
          (str(clf.__class__).split('.')[-1].replace('>','').replace("'",''), 
          scores.mean(), scores.std() * 2))

# %%
def run_models(X, y):
    run_model(LinearSVC(), X, y)
    run_model(SGDClassifier(), X, y)
    run_model(Perceptron(), X, y)
    run_model(PassiveAggressiveClassifier(), X, y)
    run_model(BernoulliNB(), X, y)
    run_model(MultinomialNB(), X, y)
    run_model(KNeighborsClassifier(), X, y)
    run_model(NearestCentroid(), X, y)
    run_model(RandomForestClassifier(n_estimators=100, max_depth=10), X, y)

# %% [markdown]
# ### BAG OF WORDS

# %%
text=titles
Documentos = copy.deepcopy(text)
Documentos
# Out:
# array([ "# Dyslexic iPhone 6 Users rejoice! Thanks @apple 'voice text' hard spell words thing past!",
#        'RT @TeamCavuto: Protesters stage #DieIn protests @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#        'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need batteries future NoW!!!!',
#        ...,
#        '@Apple [#Apple] #is developing #iPhone fires LASER BEAMS #map surroundings .... (#Monday, 8 #December)',
#        'APPLE Intraday Comments - Updated RANGE,. - PREMIUM USERS #aapl #Stockaction #trading #Stocks #MKt',
#        "RT @SaifBinS3eed: This new phone sucks can't make stand side can't wait iPhone 7 @apple fix dingles"], dtype=object)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer()

# %% [markdown]
# Se transforma el texto en una matriz de tXd, donde se indica si el token t está en el documento d

# %%
txd_matrix = vectorizer.fit_transform(Documentos)

# %% [markdown]
# Se transforma la matriz txd para que sea binaria

# %%
txd_matrix = CountVectorizer(binary=True,tokenizer=clean_tokens,stop_words='english').fit_transform(Documentos)
txd_matrix.shape
# Out:
# (3886, 9377)

# %%
run_models(txd_matrix, y_train)
# Out:
# LinearSVC accuracy: 0.72 (+/- 0.01)
# SGDClassifier accuracy: 0.69 (+/- 0.05)
# Perceptron accuracy: 0.66 (+/- 0.04)
# PassiveAggressiveClassifier accuracy: 0.71 (+/- 0.01)
# BernoulliNB accuracy: 0.71 (+/- 0.02)
# MultinomialNB accuracy: 0.69 (+/- 0.04)
# KNeighborsClassifier accuracy: 0.59 (+/- 0.04)
# NearestCentroid accuracy: 0.42 (+/- 0.02)
# RandomForestClassifier accuracy: 0.59 (+/- 0.01)

# %% [markdown]
# ### TFIDF VECTORIZER
# Una matriz de métricas tfidf para cada documento del dataset

# %%
DocumentosTFIDF = copy.deepcopy(text)
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# Transformamos la matriz de solo tf (tf_matrix) y la matriz tfidf

# %%
tf_matrix = TfidfVectorizer(use_idf=False).fit_transform(DocumentosTFIDF)
tfidf_matrix = TfidfVectorizer().fit_transform(DocumentosTFIDF)
DocumentosTFIDF
# Out:
# array([ "# Dyslexic iPhone 6 Users rejoice! Thanks @apple 'voice text' hard spell words thing past!",
#        'RT @TeamCavuto: Protesters stage #DieIn protests @Apple store NYC... Is me, anger misplaced? RETWEET agree.',
#        'RT @OneRepublic: Studio 45,000 ft. One outlet, 4 computers. @Apple need batteries future NoW!!!!',
#        ...,
#        '@Apple [#Apple] #is developing #iPhone fires LASER BEAMS #map surroundings .... (#Monday, 8 #December)',
#        'APPLE Intraday Comments - Updated RANGE,. - PREMIUM USERS #aapl #Stockaction #trading #Stocks #MKt',
#        "RT @SaifBinS3eed: This new phone sucks can't make stand side can't wait iPhone 7 @apple fix dingles"], dtype=object)

# %%
#print(tf_matrix[3107])

# %%
print(tfidf_matrix)
#nltk.download()
# Out:
#   (0, 1975)	0.361065489765
#   (0, 3229)	0.144620461154
#   (0, 6314)	0.222243880251
#   (0, 4936)	0.361065489765
#   (0, 5942)	0.211919250867
#   (0, 513)	0.0459164597084
#   (0, 6393)	0.322471057045
#   (0, 5929)	0.308298748359
#   (0, 2819)	0.262024878521
#   (0, 5553)	0.343987181221
#   (0, 6599)	0.282224636454
#   (0, 5986)	0.260065441902
#   (0, 4436)	0.297713311383
#   (1, 513)	0.0723169074671
#   (1, 5104)	0.16804641444
#   (1, 5868)	0.269790016386
#   (1, 4737)	0.278805492374
#   (1, 5597)	0.278805492374
#   (1, 1775)	0.28093873303
#   (1, 4740)	0.279226687871
#   (1, 5670)	0.245508732807
#   (1, 4237)	0.273949319987
#   (1, 3260)	0.244750575207
#   (1, 3856)	0.271648347085
#   (1, 461)	0.279226687871
#   :	:
#   (3884, 3185)	0.270092857224
#   (3884, 236)	0.131648727532
#   (3884, 1342)	0.32771559128
#   (3884, 6283)	0.341259110437
#   (3884, 4830)	0.345806131498
#   (3884, 4651)	0.32771559128
#   (3884, 5656)	0.321216232481
#   (3884, 6103)	0.294708772929
#   (3884, 5659)	0.276705830934
#   (3884, 3962)	0.314015792968
#   (3885, 3229)	0.147728470309
#   (3885, 513)	0.0469032410808
#   (3885, 5104)	0.108991406924
#   (3885, 2392)	0.212316147764
#   (3885, 4509)	0.182493150553
#   (3885, 5994)	0.223210025318
#   (3885, 4143)	0.174980189598
#   (3885, 3773)	0.20904681687
#   (3885, 1078)	0.419149487236
#   (3885, 5719)	0.274288410886
#   (3885, 5370)	0.321556743126
#   (3885, 5603)	0.299578220266
#   (3885, 6409)	0.265654455848
#   (3885, 1792)	0.351379740337
#   (3885, 5142)	0.351379740337

# %%
text1=copy.deepcopy(text)
for i in range(len(text1)):
    text1[i]=text1[i].split()

# %%
from collections import Counter
import numpy as np

# %%
#Obtener la matriz TF-IDF de los tweets
from sklearn.feature_extraction.text import TfidfVectorizer

X_1 = TfidfVectorizer(tokenizer=clean_tokens, stop_words='english').fit_transform(DocumentosTFIDF)
print(X_1)
# Out:
#   (0, 5)	0.303559988358
#   (0, 4580)	0.318631163757
#   (0, 5801)	0.141304377044
#   (0, 1727)	0.167068721561
#   (0, 8924)	0.199736189486
#   (0, 7485)	0.318631163757
#   (0, 8507)	0.192833066078
#   (0, 1896)	0.0518465202782
#   (0, 1355)	0.318631163757
#   (0, 8495)	0.318631163757
#   (0, 5390)	0.234950440333
#   (0, 8122)	0.303559988358
#   (0, 9189)	0.258808208376
#   (0, 8550)	0.241338130205
#   (0, 6937)	0.318631163757
#   (1, 1896)	0.0941901422906
#   (1, 7657)	0.171139525261
#   (1, 2718)	0.286863667307
#   (1, 7276)	0.28423240011
#   (1, 8159)	0.283803653818
#   (1, 354)	0.285975137196
#   (1, 7280)	0.284663886013
#   (1, 8229)	0.255856224339
#   (1, 6748)	0.285975137196
#   (1, 6390)	0.285098146765
#   :	:
#   (3884, 1442)	0.382441470302
#   (3884, 5761)	0.235094711922
#   (3884, 31)	0.123405978925
#   (3884, 3926)	0.285250796026
#   (3884, 8885)	0.29897869471
#   (3884, 7164)	0.285250796026
#   (3884, 920)	0.279593612419
#   (3884, 993)	0.262765715722
#   (3884, 923)	0.257366200397
#   (3884, 712)	0.273326192871
#   (3884, 7373)	0.389593308772
#   (3885, 5801)	0.164897546688
#   (3885, 1896)	0.0605031788612
#   (3885, 7657)	0.109931730172
#   (3885, 4977)	0.214621661632
#   (3885, 6999)	0.189125667799
#   (3885, 6657)	0.178367623103
#   (3885, 6318)	0.210751147768
#   (3885, 3671)	0.453051417401
#   (3885, 8296)	0.290640258147
#   (3885, 8163)	0.302020641657
#   (3885, 9013)	0.279003966689
#   (3885, 1766)	0.276524647825
#   (3885, 4407)	0.354244492633
#   (3885, 2608)	0.371832057158

# %%
print(X_1.shape,y_train.shape)
# Out:
# (3886, 9377) (3886,)

# %%
run_models(X_1, y_train)


#clf = LinearSVC(random_state = 0)
#clf.fit(X_1,y_train)

#prueba = ["a"] * X_1.shape[1]
#prueba[0] = "I loved this amazing version"
#print(prueba)
#X_5 = TfidfVectorizer(tokenizer=clean_tokens, stop_words='english').fit_transform(prueba)

#X_5
#clf.predict(X_5)
# Out:
# LinearSVC accuracy: 0.72 (+/- 0.02)
# SGDClassifier accuracy: 0.72 (+/- 0.01)
# Perceptron accuracy: 0.67 (+/- 0.05)
# PassiveAggressiveClassifier accuracy: 0.72 (+/- 0.02)
# BernoulliNB accuracy: 0.71 (+/- 0.02)
# MultinomialNB accuracy: 0.72 (+/- 0.02)
# KNeighborsClassifier accuracy: 0.69 (+/- 0.01)
# NearestCentroid accuracy: 0.52 (+/- 0.05)
# RandomForestClassifier accuracy: 0.59 (+/- 0.01)

# %% [markdown]
# ## Utilizando Word Vectors de Spacy

# %%
# !pip3 install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz --user
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz (37.4MB)
#     100% |████████████████████████████████| 37.4MB 2.2MB/s ta 0:00:0101
# Requirement already satisfied (use --upgrade to upgrade): en-core-web-sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz in /home/alulab/.local/lib/python3.6/site-packages
# Requirement already satisfied: spacy>=2.0.0a18 in /home/alulab/.local/lib/python3.6/site-packages (from en-core-web-sm==2.0.0) (2.0.12.dev0)
# Requirement already satisfied: thinc<6.11.0,>=6.10.1 in /home/alulab/.local/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (6.10.2)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /home/alulab/.local/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.28.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /home/alulab/.local/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.9.6)
# Requirement already satisfied: ujson>=1.35 in /home/alulab/.local/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.35)
# Requirement already satisfied: regex==2017.4.5 in /home/alulab/.local/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (2017.4.5)
# Requirement already satisfied: pathlib in /home/alulab/.local/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.0.1)
# Requirement already satisfied: cymem<1.32,>=1.30 in /home/alulab/.local/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.31.2)
# Requirement already satisfied: dill<0.3,>=0.2 in /home/alulab/.local/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.2.7.1)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /home/alulab/.local/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.0.0)
# Requirement already satisfied: numpy>=1.7 in /opt/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.12.1)
# Requirement already satisfied: wrapt in /opt/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.10.10)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in /opt/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.8.2)
# Requirement already satisfied: termcolor in /home/alulab/.local/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.1.0)
# Requirement already satisfied: msgpack-numpy==0.4.1 in /home/alulab/.local/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.4.1)
# Requirement already satisfied: msgpack-python in /opt/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.4.8)
# Requirement already satisfied: six<2.0.0,>=1.10.0 in /opt/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.10.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /home/alulab/.local/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (4.23.4)
# Building wheels for collected packages: en-core-web-sm
#   Running setup.py bdist_wheel for en-core-web-sm ... done
#   Stored in directory: /home/alulab/.cache/pip/wheels/54/7c/d8/f86364af8fbba7258e14adae115f18dd2c91552406edc3fdaa
# Successfully built en-core-web-sm

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp(u'This is a sentence.')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/alulab/.local/lib/python3.6/site-packages/spacy/util.py in get_lang_class(lang)
#      49         try:
# ---> 50             module = importlib.import_module('.lang.%s' % lang, 'spacy')
#      51         except ImportError:
#
# /opt/anaconda3/lib/python3.6/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /opt/anaconda3/lib/python3.6/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /opt/anaconda3/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /opt/anaconda3/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /opt/anaconda3/lib/python3.6/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /opt/anaconda3/lib/python3.6/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /opt/anaconda3/lib/python3.6/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /home/alulab/.local/lib/python3.6/site-packages/spacy/lang/en/__init__.py in <module>()
#      14 from ..norm_exceptions import BASE_NORMS
# ---> 15 from ...language import Language
#      16 from ...attrs import LANG, NORM
#
# /home/alulab/.local/lib/python3.6/site-packages/spacy/language.py in <module>()
#      14
# ---> 15 from .tokenizer import Tokenizer
#      16 from .vocab import Vocab
#
# ImportError: /home/alulab/.local/lib/python3.6/site-packages/spacy/tokenizer.cpython-36m-x86_64-linux-gnu.so: undefined symbol: _ZTINSt8ios_base7failureB5cxx11E
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-446a098811e8> in <module>()
#       1 import spacy
# ----> 2 nlp = spacy.load('en_core_web_sm')
#       3 doc = nlp(u'This is a sentence.')
#
# /home/alulab/.local/lib/python3.6/site-packages/spacy/__init__.py in load(name, **overrides)
#      13     if depr_path not in (True, False, None):
#      14         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 15     return util.load_model(name, **overrides)
#      16
#      17
#
# /home/alulab/.local/lib/python3.6/site-packages/spacy/util.py in load_model(name, **overrides)
#     112             return load_model_from_link(name, **overrides)
#     113         if is_package(name):  # installed as package
# --> 114             return load_model_from_package(name, **overrides)
#     115         if Path(name).exists():  # path to model data directory
#     116             return load_model_from_path(Path(name), **overrides)
#
# /home/alulab/.local/lib/python3.6/site-packages/spacy/util.py in load_model_from_package(name, **overrides)
#     133     """Load a model from an installed package."""
#     134     cls = importlib.import_module(name)
# --> 135     return cls.load(**overrides)
#     136
#     137
#
# /home/alulab/.local/lib/python3.6/site-packages/en_core_web_sm/__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# /home/alulab/.local/lib/python3.6/site-packages/spacy/util.py in load_model_from_init_py(init_file, **overrides)
#     171     if not model_path.exists():
#     172         raise IOError(Errors.E052.format(path=path2str(data_path)))
# --> 173     return load_model_from_path(data_path, meta, **overrides)
#     174
#     175
#
# /home/alulab/.local/lib/python3.6/site-packages/spacy/util.py in load_model_from_path(model_path, meta, **overrides)
#     141     if not meta:
#     142         meta = get_model_meta(model_path)
# --> 143     cls = get_lang_class(meta['lang'])
#     144     nlp = cls(meta=meta, **overrides)
#     145     pipeline = meta.get('pipeline', [])
#
# /home/alulab/.local/lib/python3.6/site-packages/spacy/util.py in get_lang_class(lang)
#      50             module = importlib.import_module('.lang.%s' % lang, 'spacy')
#      51         except ImportError:
# ---> 52             raise ImportError(Errors.E048.format(lang=lang))
#      53         LANGUAGES[lang] = getattr(module, module.__all__[0])
#      54     return LANGUAGES[lang]
#
# ImportError: [E048] Can't import language en from spacy.lang.

# %%
# !pip3 install --upgrade gensim --user
from gensim.models import word2vec
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/33/33/df6cb7acdcec5677ed130f4800f67509d24dbec74a03c329fcbf6b0864f0/gensim-3.4.0-cp36-cp36m-manylinux1_x86_64.whl (22.6MB)
#     100% |████████████████████████████████| 22.6MB 3.4MB/s eta 0:00:01
# Requirement not upgraded as not directly required: six>=1.5.0 in /opt/anaconda3/lib/python3.6/site-packages (from gensim) (1.10.0)
# Requirement not upgraded as not directly required: scipy>=0.18.1 in /opt/anaconda3/lib/python3.6/site-packages (from gensim) (0.19.0)
# Collecting smart-open>=1.2.1 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/4b/69/c92661a333f733510628f28b8282698b62cdead37291c8491f3271677c02/smart_open-1.5.7.tar.gz
# Requirement not upgraded as not directly required: numpy>=1.11.3 in /opt/anaconda3/lib/python3.6/site-packages (from gensim) (1.12.1)
# Requirement not upgraded as not directly required: boto>=2.32 in /opt/anaconda3/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim) (2.46.1)
# Collecting bz2file (from smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/61/39/122222b5e85cd41c391b68a99ee296584b2a2d1d233e7ee32b4532384f2d/bz2file-0.98.tar.gz
# Requirement not upgraded as not directly required: requests in /opt/anaconda3/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim) (2.14.2)
# Collecting boto3 (from smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/c2/e5/fb51cee4bd2521900f6418b22ff4a9387aecac379970419bf4003f8cd18d/boto3-1.7.33-py2.py3-none-any.whl (128kB)
#     100% |████████████████████████████████| 133kB 55.9MB/s ta 0:00:01
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Collecting s3transfer<0.2.0,>=0.1.10 (from boto3->smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/d7/14/2a0004d487464d120c9fb85313a75cd3d71a7506955be458eebfe19a6b1d/s3transfer-0.1.13-py2.py3-none-any.whl (59kB)
#     100% |████████████████████████████████| 61kB 39.0MB/s ta 0:00:01
# Collecting botocore<1.11.0,>=1.10.33 (from boto3->smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/79/91/aa2731dc3d2ed94d8fa3ff934fb0d2fd1d03171f57be95c464dcfeb2d623/botocore-1.10.33-py2.py3-none-any.whl (4.3MB)
#     100% |████████████████████████████████| 4.3MB 15.9MB/s ta 0:00:01
# Requirement not upgraded as not directly required: docutils>=0.10 in /opt/anaconda3/lib/python3.6/site-packages (from botocore<1.11.0,>=1.10.33->boto3->smart-open>=1.2.1->gensim) (0.13.1)
# Requirement not upgraded as not directly required: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /opt/anaconda3/lib/python3.6/site-packages (from botocore<1.11.0,>=1.10.33->boto3->smart-open>=1.2.1->gensim) (2.6.0)
# Building wheels for collected packages: smart-open, bz2file
#   Running setup.py bdist_wheel for smart-open ... done
#   Stored in directory: /home/alulab/.cache/pip/wheels/b1/9e/7d/bb3d3b55c597e72617140a0638c06382a5f17283881eae163e
#   Running setup.py bdist_wheel for bz2file ... done
#   Stored in directory: /home/alulab/.cache/pip/wheels/81/75/d6/e1317bf09bf1af5a30befc2a007869fa6e1f516b8f7c591cb9
# Successfully built smart-open bz2file
# Installing collected packages: bz2file, jmespath, botocore, s3transfer, boto3, smart-open, gensim
# Successfully installed boto3-1.7.33 botocore-1.10.33 bz2file-0.98 gensim-3.4.0 jmespath-0.9.3 s3transfer-0.1.13 smart-open-1.5.7

# %%
sentences = word2vec.Word2Vec(sentences=)

# %%
print(sentences)
# Out:
# <gensim.models.word2vec.Text8Corpus object at 0x7ff873b8aeb8>

# %%
# Out:
# [3.307485328321634e-05,
#  0.9509604303236153,
#  0.048740892547007926,
#  1.0940818199600276e-05,
#  2.4976291581652807e-05,
#  0.0002296851663123577]
